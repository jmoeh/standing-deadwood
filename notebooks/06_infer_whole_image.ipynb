# %%
import os
import sys
import rasterio
import wandb
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from torchvision.transforms.functional import crop
from rasterio import windows
from tqdm import tqdm
import numpy as np

# Add the parent directory to sys.path
sys.path.append(os.path.dirname(os.path.realpath(os.path.abspath(""))))

from unet.inference_dataset import DeadwoodInferenceDataset
from unet.unet_model import UNet
from unet.train_dataset import get_windows

# %%
inference_file = "/net/data_ssd/tree_mortality_orthophotos/orthophotos/uavforsat_2017_CFB050_ortho.tif"

# %%
run_id = "52dhmoq"
api = wandb.Api()
experiment = api.run(f"jmoehring/standing-deadwood-unet-pro/{run_id}")

# %%
fold: int = 0
epoch: int = 19

checkpoint_dir = f"/net/scratch/jmoehring/checkpoints/{experiment.name}"
model_checkpoint = f"fold_{fold}_epoch_{epoch}.pth"
output_dir = f"/net/scratch/jmoehring/inference/{experiment.name}"
filename = os.path.basename(inference_file)

# %%
dataset = DeadwoodInferenceDataset(inference_file, padding=64)

# %%
dataset.cropped_windows
# Out:
# [Window(col_off=64, row_off=64, width=384, height=384),
#  Window(col_off=64, row_off=448, width=384, height=384),
#  Window(col_off=64, row_off=832, width=384, height=384),
#  Window(col_off=64, row_off=1216, width=384, height=384),
#  Window(col_off=64, row_off=1600, width=384, height=384),
#  Window(col_off=64, row_off=1984, width=384, height=384),
#  Window(col_off=64, row_off=2368, width=384, height=384),
#  Window(col_off=64, row_off=2752, width=384, height=384),
#  Window(col_off=64, row_off=3136, width=384, height=384),
#  Window(col_off=64, row_off=3520, width=384, height=384),
#  Window(col_off=64, row_off=3904, width=384, height=384),
#  Window(col_off=64, row_off=4288, width=384, height=384),
#  Window(col_off=64, row_off=4672, width=384, height=384),
#  Window(col_off=64, row_off=5056, width=384, height=384),
#  Window(col_off=64, row_off=5440, width=384, height=384),
#  Window(col_off=64, row_off=5824, width=384, height=384),
#  Window(col_off=64, row_off=6208, width=384, height=384),
#  Window(col_off=64, row_off=6592, width=384, height=384),
#  Window(col_off=64, row_off=6976, width=384, height=384),
#  Window(col_off=64, row_off=7360, width=384, height=384),
#  Window(col_off=64, row_off=7744, width=384, height=384),
#  Window(col_off=64, row_off=8128, width=384, height=384),
#  Window(col_off=64, row_off=8512, width=384, height=384),
#  Window(col_off=64, row_off=8896, width=384, height=384),
#  Window(col_off=64, row_off=9280, width=384, height=384),
#  Window(col_off=64, row_off=9664, width=384, height=384),
#  Window(col_off=64, row_off=10048, width=384, height=384),
#  Window(col_off=64, row_off=10432, width=384, height=384),
#  Window(col_off=64, row_off=10816, width=384, height=384),
#  Window(col_off=64, row_off=11200, width=384, height=384),
#  Window(col_off=64, row_off=11584, width=384, height=384),
#  Window(col_off=64, row_off=11968, width=384, height=384),
#  Window(col_off=64, row_off=12352, width=384, height=384),
#  Window(col_off=64, row_off=12736, width=384, height=384),
#  Window(col_off=64, row_off=13120, width=384, height=384),
#  Window(col_off=64, row_off=13504, width=384, height=384),
#  Window(col_off=64, row_off=13888, width=384, height=384),
#  Window(col_off=64, row_off=14272, width=384, height=384),
#  Window(col_off=64, row_off=14656, width=384, height=384),
#  Window(col_off=64, row_off=15040, width=384, height=384),
#  Window(col_off=64, row_off=15424, width=384, height=384),
#  Window(col_off=64, row_off=15808, width=384, height=384),
#  Window(col_off=64, row_off=16192, width=384, height=384),
#  Window(col_off=64, row_off=16576, width=384, height=384),
#  Window(col_off=64, row_off=16960, width=384, height=384),
#  Window(col_off=64, row_off=17344, width=384, height=384),
#  Window(col_off=64, row_off=17728, width=384, height=384),
#  Window(col_off=64, row_off=18112, width=384, height=384),
#  Window(col_off=64, row_off=18496, width=384, height=384),
#  Window(col_off=64, row_off=18880, width=384, height=384),
#  Window(col_off=64, row_off=19264, width=384, height=384),
#  Window(col_off=64, row_off=19648, width=384, height=384),
#  Window(col_off=64, row_off=20032, width=384, height=384),
#  Window(col_off=64, row_off=20416, width=384, height=384),
#  Window(col_off=64, row_off=20800, width=384, height=384),
#  Window(col_off=64, row_off=21184, width=384, height=384),
#  Window(col_off=64, row_off=21568, width=384, height=384),
#  Window(col_off=64, row_off=21952, width=384, height=384),
#  Window(col_off=64, row_off=22336, width=384, height=384),
#  Window(col_off=64, row_off=22720, width=384, height=384),
#  Window(col_off=64, row_off=23104, width=384, height=384),
#  Window(col_off=64, row_off=23488, width=384, height=384),
#  Window(col_off=64, row_off=23602, width=384, height=384),
#  Window(col_off=448, row_off=64, width=384, height=384),
#  Window(col_off=448, row_off=448, width=384, height=384),
#  Window(col_off=448, row_off=832, width=384, height=384),
#  Window(col_off=448, row_off=1216, width=384, height=384),
#  Window(col_off=448, row_off=1600, width=384, height=384),
#  Window(col_off=448, row_off=1984, width=384, height=384),
#  Window(col_off=448, row_off=2368, width=384, height=384),
#  Window(col_off=448, row_off=2752, width=384, height=384),
#  Window(col_off=448, row_off=3136, width=384, height=384),
#  Window(col_off=448, row_off=3520, width=384, height=384),
#  Window(col_off=448, row_off=3904, width=384, height=384),
#  Window(col_off=448, row_off=4288, width=384, height=384),
#  Window(col_off=448, row_off=4672, width=384, height=384),
#  Window(col_off=448, row_off=5056, width=384, height=384),
#  Window(col_off=448, row_off=5440, width=384, height=384),
#  Window(col_off=448, row_off=5824, width=384, height=384),
#  Window(col_off=448, row_off=6208, width=384, height=384),
#  Window(col_off=448, row_off=6592, width=384, height=384),
#  Window(col_off=448, row_off=6976, width=384, height=384),
#  Window(col_off=448, row_off=7360, width=384, height=384),
#  Window(col_off=448, row_off=7744, width=384, height=384),
#  Window(col_off=448, row_off=8128, width=384, height=384),
#  Window(col_off=448, row_off=8512, width=384, height=384),
#  Window(col_off=448, row_off=8896, width=384, height=384),
#  Window(col_off=448, row_off=9280, width=384, height=384),
#  Window(col_off=448, row_off=9664, width=384, height=384),
#  Window(col_off=448, row_off=10048, width=384, height=384),
#  Window(col_off=448, row_off=10432, width=384, height=384),
#  Window(col_off=448, row_off=10816, width=384, height=384),
#  Window(col_off=448, row_off=11200, width=384, height=384),
#  Window(col_off=448, row_off=11584, width=384, height=384),
#  Window(col_off=448, row_off=11968, width=384, height=384),
#  Window(col_off=448, row_off=12352, width=384, height=384),
#  Window(col_off=448, row_off=12736, width=384, height=384),
#  Window(col_off=448, row_off=13120, width=384, height=384),
#  Window(col_off=448, row_off=13504, width=384, height=384),
#  Window(col_off=448, row_off=13888, width=384, height=384),
#  Window(col_off=448, row_off=14272, width=384, height=384),
#  Window(col_off=448, row_off=14656, width=384, height=384),
#  Window(col_off=448, row_off=15040, width=384, height=384),
#  Window(col_off=448, row_off=15424, width=384, height=384),
#  Window(col_off=448, row_off=15808, width=384, height=384),
#  Window(col_off=448, row_off=16192, width=384, height=384),
#  Window(col_off=448, row_off=16576, width=384, height=384),
#  Window(col_off=448, row_off=16960, width=384, height=384),
#  Window(col_off=448, row_off=17344, width=384, height=384),
#  Window(col_off=448, row_off=17728, width=384, height=384),
#  Window(col_off=448, row_off=18112, width=384, height=384),
#  Window(col_off=448, row_off=18496, width=384, height=384),
#  Window(col_off=448, row_off=18880, width=384, height=384),
#  Window(col_off=448, row_off=19264, width=384, height=384),
#  Window(col_off=448, row_off=19648, width=384, height=384),
#  Window(col_off=448, row_off=20032, width=384, height=384),
#  Window(col_off=448, row_off=20416, width=384, height=384),
#  Window(col_off=448, row_off=20800, width=384, height=384),
#  Window(col_off=448, row_off=21184, width=384, height=384),
#  Window(col_off=448, row_off=21568, width=384, height=384),
#  Window(col_off=448, row_off=21952, width=384, height=384),
#  Window(col_off=448, row_off=22336, width=384, height=384),
#  Window(col_off=448, row_off=22720, width=384, height=384),
#  Window(col_off=448, row_off=23104, width=384, height=384),
#  Window(col_off=448, row_off=23488, width=384, height=384),
#  Window(col_off=448, row_off=23602, width=384, height=384),
#  Window(col_off=832, row_off=64, width=384, height=384),
#  Window(col_off=832, row_off=448, width=384, height=384),
#  Window(col_off=832, row_off=832, width=384, height=384),
#  Window(col_off=832, row_off=1216, width=384, height=384),
#  Window(col_off=832, row_off=1600, width=384, height=384),
#  Window(col_off=832, row_off=1984, width=384, height=384),
#  Window(col_off=832, row_off=2368, width=384, height=384),
#  Window(col_off=832, row_off=2752, width=384, height=384),
#  Window(col_off=832, row_off=3136, width=384, height=384),
#  Window(col_off=832, row_off=3520, width=384, height=384),
#  Window(col_off=832, row_off=3904, width=384, height=384),
#  Window(col_off=832, row_off=4288, width=384, height=384),
#  Window(col_off=832, row_off=4672, width=384, height=384),
#  Window(col_off=832, row_off=5056, width=384, height=384),
#  Window(col_off=832, row_off=5440, width=384, height=384),
#  Window(col_off=832, row_off=5824, width=384, height=384),
#  Window(col_off=832, row_off=6208, width=384, height=384),
#  Window(col_off=832, row_off=6592, width=384, height=384),
#  Window(col_off=832, row_off=6976, width=384, height=384),
#  Window(col_off=832, row_off=7360, width=384, height=384),
#  Window(col_off=832, row_off=7744, width=384, height=384),
#  Window(col_off=832, row_off=8128, width=384, height=384),
#  Window(col_off=832, row_off=8512, width=384, height=384),
#  Window(col_off=832, row_off=8896, width=384, height=384),
#  Window(col_off=832, row_off=9280, width=384, height=384),
#  Window(col_off=832, row_off=9664, width=384, height=384),
#  Window(col_off=832, row_off=10048, width=384, height=384),
#  Window(col_off=832, row_off=10432, width=384, height=384),
#  Window(col_off=832, row_off=10816, width=384, height=384),
#  Window(col_off=832, row_off=11200, width=384, height=384),
#  Window(col_off=832, row_off=11584, width=384, height=384),
#  Window(col_off=832, row_off=11968, width=384, height=384),
#  Window(col_off=832, row_off=12352, width=384, height=384),
#  Window(col_off=832, row_off=12736, width=384, height=384),
#  Window(col_off=832, row_off=13120, width=384, height=384),
#  Window(col_off=832, row_off=13504, width=384, height=384),
#  Window(col_off=832, row_off=13888, width=384, height=384),
#  Window(col_off=832, row_off=14272, width=384, height=384),
#  Window(col_off=832, row_off=14656, width=384, height=384),
#  Window(col_off=832, row_off=15040, width=384, height=384),
#  Window(col_off=832, row_off=15424, width=384, height=384),
#  Window(col_off=832, row_off=15808, width=384, height=384),
#  Window(col_off=832, row_off=16192, width=384, height=384),
#  Window(col_off=832, row_off=16576, width=384, height=384),
#  Window(col_off=832, row_off=16960, width=384, height=384),
#  Window(col_off=832, row_off=17344, width=384, height=384),
#  Window(col_off=832, row_off=17728, width=384, height=384),
#  Window(col_off=832, row_off=18112, width=384, height=384),
#  Window(col_off=832, row_off=18496, width=384, height=384),
#  Window(col_off=832, row_off=18880, width=384, height=384),
#  Window(col_off=832, row_off=19264, width=384, height=384),
#  Window(col_off=832, row_off=19648, width=384, height=384),
#  Window(col_off=832, row_off=20032, width=384, height=384),
#  Window(col_off=832, row_off=20416, width=384, height=384),
#  Window(col_off=832, row_off=20800, width=384, height=384),
#  Window(col_off=832, row_off=21184, width=384, height=384),
#  Window(col_off=832, row_off=21568, width=384, height=384),
#  Window(col_off=832, row_off=21952, width=384, height=384),
#  Window(col_off=832, row_off=22336, width=384, height=384),
#  Window(col_off=832, row_off=22720, width=384, height=384),
#  Window(col_off=832, row_off=23104, width=384, height=384),
#  Window(col_off=832, row_off=23488, width=384, height=384),
#  Window(col_off=832, row_off=23602, width=384, height=384),
#  Window(col_off=1216, row_off=64, width=384, height=384),
#  Window(col_off=1216, row_off=448, width=384, height=384),
#  Window(col_off=1216, row_off=832, width=384, height=384),
#  Window(col_off=1216, row_off=1216, width=384, height=384),
#  Window(col_off=1216, row_off=1600, width=384, height=384),
#  Window(col_off=1216, row_off=1984, width=384, height=384),
#  Window(col_off=1216, row_off=2368, width=384, height=384),
#  Window(col_off=1216, row_off=2752, width=384, height=384),
#  Window(col_off=1216, row_off=3136, width=384, height=384),
#  Window(col_off=1216, row_off=3520, width=384, height=384),
#  Window(col_off=1216, row_off=3904, width=384, height=384),
#  Window(col_off=1216, row_off=4288, width=384, height=384),
#  Window(col_off=1216, row_off=4672, width=384, height=384),
#  Window(col_off=1216, row_off=5056, width=384, height=384),
#  Window(col_off=1216, row_off=5440, width=384, height=384),
#  Window(col_off=1216, row_off=5824, width=384, height=384),
#  Window(col_off=1216, row_off=6208, width=384, height=384),
#  Window(col_off=1216, row_off=6592, width=384, height=384),
#  Window(col_off=1216, row_off=6976, width=384, height=384),
#  Window(col_off=1216, row_off=7360, width=384, height=384),
#  Window(col_off=1216, row_off=7744, width=384, height=384),
#  Window(col_off=1216, row_off=8128, width=384, height=384),
#  Window(col_off=1216, row_off=8512, width=384, height=384),
#  Window(col_off=1216, row_off=8896, width=384, height=384),
#  Window(col_off=1216, row_off=9280, width=384, height=384),
#  Window(col_off=1216, row_off=9664, width=384, height=384),
#  Window(col_off=1216, row_off=10048, width=384, height=384),
#  Window(col_off=1216, row_off=10432, width=384, height=384),
#  Window(col_off=1216, row_off=10816, width=384, height=384),
#  Window(col_off=1216, row_off=11200, width=384, height=384),
#  Window(col_off=1216, row_off=11584, width=384, height=384),
#  Window(col_off=1216, row_off=11968, width=384, height=384),
#  Window(col_off=1216, row_off=12352, width=384, height=384),
#  Window(col_off=1216, row_off=12736, width=384, height=384),
#  Window(col_off=1216, row_off=13120, width=384, height=384),
#  Window(col_off=1216, row_off=13504, width=384, height=384),
#  Window(col_off=1216, row_off=13888, width=384, height=384),
#  Window(col_off=1216, row_off=14272, width=384, height=384),
#  Window(col_off=1216, row_off=14656, width=384, height=384),
#  Window(col_off=1216, row_off=15040, width=384, height=384),
#  Window(col_off=1216, row_off=15424, width=384, height=384),
#  Window(col_off=1216, row_off=15808, width=384, height=384),
#  Window(col_off=1216, row_off=16192, width=384, height=384),
#  Window(col_off=1216, row_off=16576, width=384, height=384),
#  Window(col_off=1216, row_off=16960, width=384, height=384),
#  Window(col_off=1216, row_off=17344, width=384, height=384),
#  Window(col_off=1216, row_off=17728, width=384, height=384),
#  Window(col_off=1216, row_off=18112, width=384, height=384),
#  Window(col_off=1216, row_off=18496, width=384, height=384),
#  Window(col_off=1216, row_off=18880, width=384, height=384),
#  Window(col_off=1216, row_off=19264, width=384, height=384),
#  Window(col_off=1216, row_off=19648, width=384, height=384),
#  Window(col_off=1216, row_off=20032, width=384, height=384),
#  Window(col_off=1216, row_off=20416, width=384, height=384),
#  Window(col_off=1216, row_off=20800, width=384, height=384),
#  Window(col_off=1216, row_off=21184, width=384, height=384),
#  Window(col_off=1216, row_off=21568, width=384, height=384),
#  Window(col_off=1216, row_off=21952, width=384, height=384),
#  Window(col_off=1216, row_off=22336, width=384, height=384),
#  Window(col_off=1216, row_off=22720, width=384, height=384),
#  Window(col_off=1216, row_off=23104, width=384, height=384),
#  Window(col_off=1216, row_off=23488, width=384, height=384),
#  Window(col_off=1216, row_off=23602, width=384, height=384),
#  Window(col_off=1600, row_off=64, width=384, height=384),
#  Window(col_off=1600, row_off=448, width=384, height=384),
#  Window(col_off=1600, row_off=832, width=384, height=384),
#  Window(col_off=1600, row_off=1216, width=384, height=384),
#  Window(col_off=1600, row_off=1600, width=384, height=384),
#  Window(col_off=1600, row_off=1984, width=384, height=384),
#  Window(col_off=1600, row_off=2368, width=384, height=384),
#  Window(col_off=1600, row_off=2752, width=384, height=384),
#  Window(col_off=1600, row_off=3136, width=384, height=384),
#  Window(col_off=1600, row_off=3520, width=384, height=384),
#  Window(col_off=1600, row_off=3904, width=384, height=384),
#  Window(col_off=1600, row_off=4288, width=384, height=384),
#  Window(col_off=1600, row_off=4672, width=384, height=384),
#  Window(col_off=1600, row_off=5056, width=384, height=384),
#  Window(col_off=1600, row_off=5440, width=384, height=384),
#  Window(col_off=1600, row_off=5824, width=384, height=384),
#  Window(col_off=1600, row_off=6208, width=384, height=384),
#  Window(col_off=1600, row_off=6592, width=384, height=384),
#  Window(col_off=1600, row_off=6976, width=384, height=384),
#  Window(col_off=1600, row_off=7360, width=384, height=384),
#  Window(col_off=1600, row_off=7744, width=384, height=384),
#  Window(col_off=1600, row_off=8128, width=384, height=384),
#  Window(col_off=1600, row_off=8512, width=384, height=384),
#  Window(col_off=1600, row_off=8896, width=384, height=384),
#  Window(col_off=1600, row_off=9280, width=384, height=384),
#  Window(col_off=1600, row_off=9664, width=384, height=384),
#  Window(col_off=1600, row_off=10048, width=384, height=384),
#  Window(col_off=1600, row_off=10432, width=384, height=384),
#  Window(col_off=1600, row_off=10816, width=384, height=384),
#  Window(col_off=1600, row_off=11200, width=384, height=384),
#  Window(col_off=1600, row_off=11584, width=384, height=384),
#  Window(col_off=1600, row_off=11968, width=384, height=384),
#  Window(col_off=1600, row_off=12352, width=384, height=384),
#  Window(col_off=1600, row_off=12736, width=384, height=384),
#  Window(col_off=1600, row_off=13120, width=384, height=384),
#  Window(col_off=1600, row_off=13504, width=384, height=384),
#  Window(col_off=1600, row_off=13888, width=384, height=384),
#  Window(col_off=1600, row_off=14272, width=384, height=384),
#  Window(col_off=1600, row_off=14656, width=384, height=384),
#  Window(col_off=1600, row_off=15040, width=384, height=384),
#  Window(col_off=1600, row_off=15424, width=384, height=384),
#  Window(col_off=1600, row_off=15808, width=384, height=384),
#  Window(col_off=1600, row_off=16192, width=384, height=384),
#  Window(col_off=1600, row_off=16576, width=384, height=384),
#  Window(col_off=1600, row_off=16960, width=384, height=384),
#  Window(col_off=1600, row_off=17344, width=384, height=384),
#  Window(col_off=1600, row_off=17728, width=384, height=384),
#  Window(col_off=1600, row_off=18112, width=384, height=384),
#  Window(col_off=1600, row_off=18496, width=384, height=384),
#  Window(col_off=1600, row_off=18880, width=384, height=384),
#  Window(col_off=1600, row_off=19264, width=384, height=384),
#  Window(col_off=1600, row_off=19648, width=384, height=384),
#  Window(col_off=1600, row_off=20032, width=384, height=384),
#  Window(col_off=1600, row_off=20416, width=384, height=384),
#  Window(col_off=1600, row_off=20800, width=384, height=384),
#  Window(col_off=1600, row_off=21184, width=384, height=384),
#  Window(col_off=1600, row_off=21568, width=384, height=384),
#  Window(col_off=1600, row_off=21952, width=384, height=384),
#  Window(col_off=1600, row_off=22336, width=384, height=384),
#  Window(col_off=1600, row_off=22720, width=384, height=384),
#  Window(col_off=1600, row_off=23104, width=384, height=384),
#  Window(col_off=1600, row_off=23488, width=384, height=384),
#  Window(col_off=1600, row_off=23602, width=384, height=384),
#  Window(col_off=1984, row_off=64, width=384, height=384),
#  Window(col_off=1984, row_off=448, width=384, height=384),
#  Window(col_off=1984, row_off=832, width=384, height=384),
#  Window(col_off=1984, row_off=1216, width=384, height=384),
#  Window(col_off=1984, row_off=1600, width=384, height=384),
#  Window(col_off=1984, row_off=1984, width=384, height=384),
#  Window(col_off=1984, row_off=2368, width=384, height=384),
#  Window(col_off=1984, row_off=2752, width=384, height=384),
#  Window(col_off=1984, row_off=3136, width=384, height=384),
#  Window(col_off=1984, row_off=3520, width=384, height=384),
#  Window(col_off=1984, row_off=3904, width=384, height=384),
#  Window(col_off=1984, row_off=4288, width=384, height=384),
#  Window(col_off=1984, row_off=4672, width=384, height=384),
#  Window(col_off=1984, row_off=5056, width=384, height=384),
#  Window(col_off=1984, row_off=5440, width=384, height=384),
#  Window(col_off=1984, row_off=5824, width=384, height=384),
#  Window(col_off=1984, row_off=6208, width=384, height=384),
#  Window(col_off=1984, row_off=6592, width=384, height=384),
#  Window(col_off=1984, row_off=6976, width=384, height=384),
#  Window(col_off=1984, row_off=7360, width=384, height=384),
#  Window(col_off=1984, row_off=7744, width=384, height=384),
#  Window(col_off=1984, row_off=8128, width=384, height=384),
#  Window(col_off=1984, row_off=8512, width=384, height=384),
#  Window(col_off=1984, row_off=8896, width=384, height=384),
#  Window(col_off=1984, row_off=9280, width=384, height=384),
#  Window(col_off=1984, row_off=9664, width=384, height=384),
#  Window(col_off=1984, row_off=10048, width=384, height=384),
#  Window(col_off=1984, row_off=10432, width=384, height=384),
#  Window(col_off=1984, row_off=10816, width=384, height=384),
#  Window(col_off=1984, row_off=11200, width=384, height=384),
#  Window(col_off=1984, row_off=11584, width=384, height=384),
#  Window(col_off=1984, row_off=11968, width=384, height=384),
#  Window(col_off=1984, row_off=12352, width=384, height=384),
#  Window(col_off=1984, row_off=12736, width=384, height=384),
#  Window(col_off=1984, row_off=13120, width=384, height=384),
#  Window(col_off=1984, row_off=13504, width=384, height=384),
#  Window(col_off=1984, row_off=13888, width=384, height=384),
#  Window(col_off=1984, row_off=14272, width=384, height=384),
#  Window(col_off=1984, row_off=14656, width=384, height=384),
#  Window(col_off=1984, row_off=15040, width=384, height=384),
#  Window(col_off=1984, row_off=15424, width=384, height=384),
#  Window(col_off=1984, row_off=15808, width=384, height=384),
#  Window(col_off=1984, row_off=16192, width=384, height=384),
#  Window(col_off=1984, row_off=16576, width=384, height=384),
#  Window(col_off=1984, row_off=16960, width=384, height=384),
#  Window(col_off=1984, row_off=17344, width=384, height=384),
#  Window(col_off=1984, row_off=17728, width=384, height=384),
#  Window(col_off=1984, row_off=18112, width=384, height=384),
#  Window(col_off=1984, row_off=18496, width=384, height=384),
#  Window(col_off=1984, row_off=18880, width=384, height=384),
#  Window(col_off=1984, row_off=19264, width=384, height=384),
#  Window(col_off=1984, row_off=19648, width=384, height=384),
#  Window(col_off=1984, row_off=20032, width=384, height=384),
#  Window(col_off=1984, row_off=20416, width=384, height=384),
#  Window(col_off=1984, row_off=20800, width=384, height=384),
#  Window(col_off=1984, row_off=21184, width=384, height=384),
#  Window(col_off=1984, row_off=21568, width=384, height=384),
#  Window(col_off=1984, row_off=21952, width=384, height=384),
#  Window(col_off=1984, row_off=22336, width=384, height=384),
#  Window(col_off=1984, row_off=22720, width=384, height=384),
#  Window(col_off=1984, row_off=23104, width=384, height=384),
#  Window(col_off=1984, row_off=23488, width=384, height=384),
#  Window(col_off=1984, row_off=23602, width=384, height=384),
#  Window(col_off=2368, row_off=64, width=384, height=384),
#  Window(col_off=2368, row_off=448, width=384, height=384),
#  Window(col_off=2368, row_off=832, width=384, height=384),
#  Window(col_off=2368, row_off=1216, width=384, height=384),
#  Window(col_off=2368, row_off=1600, width=384, height=384),
#  Window(col_off=2368, row_off=1984, width=384, height=384),
#  Window(col_off=2368, row_off=2368, width=384, height=384),
#  Window(col_off=2368, row_off=2752, width=384, height=384),
#  Window(col_off=2368, row_off=3136, width=384, height=384),
#  Window(col_off=2368, row_off=3520, width=384, height=384),
#  Window(col_off=2368, row_off=3904, width=384, height=384),
#  Window(col_off=2368, row_off=4288, width=384, height=384),
#  Window(col_off=2368, row_off=4672, width=384, height=384),
#  Window(col_off=2368, row_off=5056, width=384, height=384),
#  Window(col_off=2368, row_off=5440, width=384, height=384),
#  Window(col_off=2368, row_off=5824, width=384, height=384),
#  Window(col_off=2368, row_off=6208, width=384, height=384),
#  Window(col_off=2368, row_off=6592, width=384, height=384),
#  Window(col_off=2368, row_off=6976, width=384, height=384),
#  Window(col_off=2368, row_off=7360, width=384, height=384),
#  Window(col_off=2368, row_off=7744, width=384, height=384),
#  Window(col_off=2368, row_off=8128, width=384, height=384),
#  Window(col_off=2368, row_off=8512, width=384, height=384),
#  Window(col_off=2368, row_off=8896, width=384, height=384),
#  Window(col_off=2368, row_off=9280, width=384, height=384),
#  Window(col_off=2368, row_off=9664, width=384, height=384),
#  Window(col_off=2368, row_off=10048, width=384, height=384),
#  Window(col_off=2368, row_off=10432, width=384, height=384),
#  Window(col_off=2368, row_off=10816, width=384, height=384),
#  Window(col_off=2368, row_off=11200, width=384, height=384),
#  Window(col_off=2368, row_off=11584, width=384, height=384),
#  Window(col_off=2368, row_off=11968, width=384, height=384),
#  Window(col_off=2368, row_off=12352, width=384, height=384),
#  Window(col_off=2368, row_off=12736, width=384, height=384),
#  Window(col_off=2368, row_off=13120, width=384, height=384),
#  Window(col_off=2368, row_off=13504, width=384, height=384),
#  Window(col_off=2368, row_off=13888, width=384, height=384),
#  Window(col_off=2368, row_off=14272, width=384, height=384),
#  Window(col_off=2368, row_off=14656, width=384, height=384),
#  Window(col_off=2368, row_off=15040, width=384, height=384),
#  Window(col_off=2368, row_off=15424, width=384, height=384),
#  Window(col_off=2368, row_off=15808, width=384, height=384),
#  Window(col_off=2368, row_off=16192, width=384, height=384),
#  Window(col_off=2368, row_off=16576, width=384, height=384),
#  Window(col_off=2368, row_off=16960, width=384, height=384),
#  Window(col_off=2368, row_off=17344, width=384, height=384),
#  Window(col_off=2368, row_off=17728, width=384, height=384),
#  Window(col_off=2368, row_off=18112, width=384, height=384),
#  Window(col_off=2368, row_off=18496, width=384, height=384),
#  Window(col_off=2368, row_off=18880, width=384, height=384),
#  Window(col_off=2368, row_off=19264, width=384, height=384),
#  Window(col_off=2368, row_off=19648, width=384, height=384),
#  Window(col_off=2368, row_off=20032, width=384, height=384),
#  Window(col_off=2368, row_off=20416, width=384, height=384),
#  Window(col_off=2368, row_off=20800, width=384, height=384),
#  Window(col_off=2368, row_off=21184, width=384, height=384),
#  Window(col_off=2368, row_off=21568, width=384, height=384),
#  Window(col_off=2368, row_off=21952, width=384, height=384),
#  Window(col_off=2368, row_off=22336, width=384, height=384),
#  Window(col_off=2368, row_off=22720, width=384, height=384),
#  Window(col_off=2368, row_off=23104, width=384, height=384),
#  Window(col_off=2368, row_off=23488, width=384, height=384),
#  Window(col_off=2368, row_off=23602, width=384, height=384),
#  Window(col_off=2752, row_off=64, width=384, height=384),
#  Window(col_off=2752, row_off=448, width=384, height=384),
#  Window(col_off=2752, row_off=832, width=384, height=384),
#  Window(col_off=2752, row_off=1216, width=384, height=384),
#  Window(col_off=2752, row_off=1600, width=384, height=384),
#  Window(col_off=2752, row_off=1984, width=384, height=384),
#  Window(col_off=2752, row_off=2368, width=384, height=384),
#  Window(col_off=2752, row_off=2752, width=384, height=384),
#  Window(col_off=2752, row_off=3136, width=384, height=384),
#  Window(col_off=2752, row_off=3520, width=384, height=384),
#  Window(col_off=2752, row_off=3904, width=384, height=384),
#  Window(col_off=2752, row_off=4288, width=384, height=384),
#  Window(col_off=2752, row_off=4672, width=384, height=384),
#  Window(col_off=2752, row_off=5056, width=384, height=384),
#  Window(col_off=2752, row_off=5440, width=384, height=384),
#  Window(col_off=2752, row_off=5824, width=384, height=384),
#  Window(col_off=2752, row_off=6208, width=384, height=384),
#  Window(col_off=2752, row_off=6592, width=384, height=384),
#  Window(col_off=2752, row_off=6976, width=384, height=384),
#  Window(col_off=2752, row_off=7360, width=384, height=384),
#  Window(col_off=2752, row_off=7744, width=384, height=384),
#  Window(col_off=2752, row_off=8128, width=384, height=384),
#  Window(col_off=2752, row_off=8512, width=384, height=384),
#  Window(col_off=2752, row_off=8896, width=384, height=384),
#  Window(col_off=2752, row_off=9280, width=384, height=384),
#  Window(col_off=2752, row_off=9664, width=384, height=384),
#  Window(col_off=2752, row_off=10048, width=384, height=384),
#  Window(col_off=2752, row_off=10432, width=384, height=384),
#  Window(col_off=2752, row_off=10816, width=384, height=384),
#  Window(col_off=2752, row_off=11200, width=384, height=384),
#  Window(col_off=2752, row_off=11584, width=384, height=384),
#  Window(col_off=2752, row_off=11968, width=384, height=384),
#  Window(col_off=2752, row_off=12352, width=384, height=384),
#  Window(col_off=2752, row_off=12736, width=384, height=384),
#  Window(col_off=2752, row_off=13120, width=384, height=384),
#  Window(col_off=2752, row_off=13504, width=384, height=384),
#  Window(col_off=2752, row_off=13888, width=384, height=384),
#  Window(col_off=2752, row_off=14272, width=384, height=384),
#  Window(col_off=2752, row_off=14656, width=384, height=384),
#  Window(col_off=2752, row_off=15040, width=384, height=384),
#  Window(col_off=2752, row_off=15424, width=384, height=384),
#  Window(col_off=2752, row_off=15808, width=384, height=384),
#  Window(col_off=2752, row_off=16192, width=384, height=384),
#  Window(col_off=2752, row_off=16576, width=384, height=384),
#  Window(col_off=2752, row_off=16960, width=384, height=384),
#  Window(col_off=2752, row_off=17344, width=384, height=384),
#  Window(col_off=2752, row_off=17728, width=384, height=384),
#  Window(col_off=2752, row_off=18112, width=384, height=384),
#  Window(col_off=2752, row_off=18496, width=384, height=384),
#  Window(col_off=2752, row_off=18880, width=384, height=384),
#  Window(col_off=2752, row_off=19264, width=384, height=384),
#  Window(col_off=2752, row_off=19648, width=384, height=384),
#  Window(col_off=2752, row_off=20032, width=384, height=384),
#  Window(col_off=2752, row_off=20416, width=384, height=384),
#  Window(col_off=2752, row_off=20800, width=384, height=384),
#  Window(col_off=2752, row_off=21184, width=384, height=384),
#  Window(col_off=2752, row_off=21568, width=384, height=384),
#  Window(col_off=2752, row_off=21952, width=384, height=384),
#  Window(col_off=2752, row_off=22336, width=384, height=384),
#  Window(col_off=2752, row_off=22720, width=384, height=384),
#  Window(col_off=2752, row_off=23104, width=384, height=384),
#  Window(col_off=2752, row_off=23488, width=384, height=384),
#  Window(col_off=2752, row_off=23602, width=384, height=384),
#  Window(col_off=3136, row_off=64, width=384, height=384),
#  Window(col_off=3136, row_off=448, width=384, height=384),
#  Window(col_off=3136, row_off=832, width=384, height=384),
#  Window(col_off=3136, row_off=1216, width=384, height=384),
#  Window(col_off=3136, row_off=1600, width=384, height=384),
#  Window(col_off=3136, row_off=1984, width=384, height=384),
#  Window(col_off=3136, row_off=2368, width=384, height=384),
#  Window(col_off=3136, row_off=2752, width=384, height=384),
#  Window(col_off=3136, row_off=3136, width=384, height=384),
#  Window(col_off=3136, row_off=3520, width=384, height=384),
#  Window(col_off=3136, row_off=3904, width=384, height=384),
#  Window(col_off=3136, row_off=4288, width=384, height=384),
#  Window(col_off=3136, row_off=4672, width=384, height=384),
#  Window(col_off=3136, row_off=5056, width=384, height=384),
#  Window(col_off=3136, row_off=5440, width=384, height=384),
#  Window(col_off=3136, row_off=5824, width=384, height=384),
#  Window(col_off=3136, row_off=6208, width=384, height=384),
#  Window(col_off=3136, row_off=6592, width=384, height=384),
#  Window(col_off=3136, row_off=6976, width=384, height=384),
#  Window(col_off=3136, row_off=7360, width=384, height=384),
#  Window(col_off=3136, row_off=7744, width=384, height=384),
#  Window(col_off=3136, row_off=8128, width=384, height=384),
#  Window(col_off=3136, row_off=8512, width=384, height=384),
#  Window(col_off=3136, row_off=8896, width=384, height=384),
#  Window(col_off=3136, row_off=9280, width=384, height=384),
#  Window(col_off=3136, row_off=9664, width=384, height=384),
#  Window(col_off=3136, row_off=10048, width=384, height=384),
#  Window(col_off=3136, row_off=10432, width=384, height=384),
#  Window(col_off=3136, row_off=10816, width=384, height=384),
#  Window(col_off=3136, row_off=11200, width=384, height=384),
#  Window(col_off=3136, row_off=11584, width=384, height=384),
#  Window(col_off=3136, row_off=11968, width=384, height=384),
#  Window(col_off=3136, row_off=12352, width=384, height=384),
#  Window(col_off=3136, row_off=12736, width=384, height=384),
#  Window(col_off=3136, row_off=13120, width=384, height=384),
#  Window(col_off=3136, row_off=13504, width=384, height=384),
#  Window(col_off=3136, row_off=13888, width=384, height=384),
#  Window(col_off=3136, row_off=14272, width=384, height=384),
#  Window(col_off=3136, row_off=14656, width=384, height=384),
#  Window(col_off=3136, row_off=15040, width=384, height=384),
#  Window(col_off=3136, row_off=15424, width=384, height=384),
#  Window(col_off=3136, row_off=15808, width=384, height=384),
#  Window(col_off=3136, row_off=16192, width=384, height=384),
#  Window(col_off=3136, row_off=16576, width=384, height=384),
#  Window(col_off=3136, row_off=16960, width=384, height=384),
#  Window(col_off=3136, row_off=17344, width=384, height=384),
#  Window(col_off=3136, row_off=17728, width=384, height=384),
#  Window(col_off=3136, row_off=18112, width=384, height=384),
#  Window(col_off=3136, row_off=18496, width=384, height=384),
#  Window(col_off=3136, row_off=18880, width=384, height=384),
#  Window(col_off=3136, row_off=19264, width=384, height=384),
#  Window(col_off=3136, row_off=19648, width=384, height=384),
#  Window(col_off=3136, row_off=20032, width=384, height=384),
#  Window(col_off=3136, row_off=20416, width=384, height=384),
#  Window(col_off=3136, row_off=20800, width=384, height=384),
#  Window(col_off=3136, row_off=21184, width=384, height=384),
#  Window(col_off=3136, row_off=21568, width=384, height=384),
#  Window(col_off=3136, row_off=21952, width=384, height=384),
#  Window(col_off=3136, row_off=22336, width=384, height=384),
#  Window(col_off=3136, row_off=22720, width=384, height=384),
#  Window(col_off=3136, row_off=23104, width=384, height=384),
#  Window(col_off=3136, row_off=23488, width=384, height=384),
#  Window(col_off=3136, row_off=23602, width=384, height=384),
#  Window(col_off=3520, row_off=64, width=384, height=384),
#  Window(col_off=3520, row_off=448, width=384, height=384),
#  Window(col_off=3520, row_off=832, width=384, height=384),
#  Window(col_off=3520, row_off=1216, width=384, height=384),
#  Window(col_off=3520, row_off=1600, width=384, height=384),
#  Window(col_off=3520, row_off=1984, width=384, height=384),
#  Window(col_off=3520, row_off=2368, width=384, height=384),
#  Window(col_off=3520, row_off=2752, width=384, height=384),
#  Window(col_off=3520, row_off=3136, width=384, height=384),
#  Window(col_off=3520, row_off=3520, width=384, height=384),
#  Window(col_off=3520, row_off=3904, width=384, height=384),
#  Window(col_off=3520, row_off=4288, width=384, height=384),
#  Window(col_off=3520, row_off=4672, width=384, height=384),
#  Window(col_off=3520, row_off=5056, width=384, height=384),
#  Window(col_off=3520, row_off=5440, width=384, height=384),
#  Window(col_off=3520, row_off=5824, width=384, height=384),
#  Window(col_off=3520, row_off=6208, width=384, height=384),
#  Window(col_off=3520, row_off=6592, width=384, height=384),
#  Window(col_off=3520, row_off=6976, width=384, height=384),
#  Window(col_off=3520, row_off=7360, width=384, height=384),
#  Window(col_off=3520, row_off=7744, width=384, height=384),
#  Window(col_off=3520, row_off=8128, width=384, height=384),
#  Window(col_off=3520, row_off=8512, width=384, height=384),
#  Window(col_off=3520, row_off=8896, width=384, height=384),
#  Window(col_off=3520, row_off=9280, width=384, height=384),
#  Window(col_off=3520, row_off=9664, width=384, height=384),
#  Window(col_off=3520, row_off=10048, width=384, height=384),
#  Window(col_off=3520, row_off=10432, width=384, height=384),
#  Window(col_off=3520, row_off=10816, width=384, height=384),
#  Window(col_off=3520, row_off=11200, width=384, height=384),
#  Window(col_off=3520, row_off=11584, width=384, height=384),
#  Window(col_off=3520, row_off=11968, width=384, height=384),
#  Window(col_off=3520, row_off=12352, width=384, height=384),
#  Window(col_off=3520, row_off=12736, width=384, height=384),
#  Window(col_off=3520, row_off=13120, width=384, height=384),
#  Window(col_off=3520, row_off=13504, width=384, height=384),
#  Window(col_off=3520, row_off=13888, width=384, height=384),
#  Window(col_off=3520, row_off=14272, width=384, height=384),
#  Window(col_off=3520, row_off=14656, width=384, height=384),
#  Window(col_off=3520, row_off=15040, width=384, height=384),
#  Window(col_off=3520, row_off=15424, width=384, height=384),
#  Window(col_off=3520, row_off=15808, width=384, height=384),
#  Window(col_off=3520, row_off=16192, width=384, height=384),
#  Window(col_off=3520, row_off=16576, width=384, height=384),
#  Window(col_off=3520, row_off=16960, width=384, height=384),
#  Window(col_off=3520, row_off=17344, width=384, height=384),
#  Window(col_off=3520, row_off=17728, width=384, height=384),
#  Window(col_off=3520, row_off=18112, width=384, height=384),
#  Window(col_off=3520, row_off=18496, width=384, height=384),
#  Window(col_off=3520, row_off=18880, width=384, height=384),
#  Window(col_off=3520, row_off=19264, width=384, height=384),
#  Window(col_off=3520, row_off=19648, width=384, height=384),
#  Window(col_off=3520, row_off=20032, width=384, height=384),
#  Window(col_off=3520, row_off=20416, width=384, height=384),
#  Window(col_off=3520, row_off=20800, width=384, height=384),
#  Window(col_off=3520, row_off=21184, width=384, height=384),
#  Window(col_off=3520, row_off=21568, width=384, height=384),
#  Window(col_off=3520, row_off=21952, width=384, height=384),
#  Window(col_off=3520, row_off=22336, width=384, height=384),
#  Window(col_off=3520, row_off=22720, width=384, height=384),
#  Window(col_off=3520, row_off=23104, width=384, height=384),
#  Window(col_off=3520, row_off=23488, width=384, height=384),
#  Window(col_off=3520, row_off=23602, width=384, height=384),
#  Window(col_off=3904, row_off=64, width=384, height=384),
#  Window(col_off=3904, row_off=448, width=384, height=384),
#  Window(col_off=3904, row_off=832, width=384, height=384),
#  Window(col_off=3904, row_off=1216, width=384, height=384),
#  Window(col_off=3904, row_off=1600, width=384, height=384),
#  Window(col_off=3904, row_off=1984, width=384, height=384),
#  Window(col_off=3904, row_off=2368, width=384, height=384),
#  Window(col_off=3904, row_off=2752, width=384, height=384),
#  Window(col_off=3904, row_off=3136, width=384, height=384),
#  Window(col_off=3904, row_off=3520, width=384, height=384),
#  Window(col_off=3904, row_off=3904, width=384, height=384),
#  Window(col_off=3904, row_off=4288, width=384, height=384),
#  Window(col_off=3904, row_off=4672, width=384, height=384),
#  Window(col_off=3904, row_off=5056, width=384, height=384),
#  Window(col_off=3904, row_off=5440, width=384, height=384),
#  Window(col_off=3904, row_off=5824, width=384, height=384),
#  Window(col_off=3904, row_off=6208, width=384, height=384),
#  Window(col_off=3904, row_off=6592, width=384, height=384),
#  Window(col_off=3904, row_off=6976, width=384, height=384),
#  Window(col_off=3904, row_off=7360, width=384, height=384),
#  Window(col_off=3904, row_off=7744, width=384, height=384),
#  Window(col_off=3904, row_off=8128, width=384, height=384),
#  Window(col_off=3904, row_off=8512, width=384, height=384),
#  Window(col_off=3904, row_off=8896, width=384, height=384),
#  Window(col_off=3904, row_off=9280, width=384, height=384),
#  Window(col_off=3904, row_off=9664, width=384, height=384),
#  Window(col_off=3904, row_off=10048, width=384, height=384),
#  Window(col_off=3904, row_off=10432, width=384, height=384),
#  Window(col_off=3904, row_off=10816, width=384, height=384),
#  Window(col_off=3904, row_off=11200, width=384, height=384),
#  Window(col_off=3904, row_off=11584, width=384, height=384),
#  Window(col_off=3904, row_off=11968, width=384, height=384),
#  Window(col_off=3904, row_off=12352, width=384, height=384),
#  Window(col_off=3904, row_off=12736, width=384, height=384),
#  Window(col_off=3904, row_off=13120, width=384, height=384),
#  Window(col_off=3904, row_off=13504, width=384, height=384),
#  Window(col_off=3904, row_off=13888, width=384, height=384),
#  Window(col_off=3904, row_off=14272, width=384, height=384),
#  Window(col_off=3904, row_off=14656, width=384, height=384),
#  Window(col_off=3904, row_off=15040, width=384, height=384),
#  Window(col_off=3904, row_off=15424, width=384, height=384),
#  Window(col_off=3904, row_off=15808, width=384, height=384),
#  Window(col_off=3904, row_off=16192, width=384, height=384),
#  Window(col_off=3904, row_off=16576, width=384, height=384),
#  Window(col_off=3904, row_off=16960, width=384, height=384),
#  Window(col_off=3904, row_off=17344, width=384, height=384),
#  Window(col_off=3904, row_off=17728, width=384, height=384),
#  Window(col_off=3904, row_off=18112, width=384, height=384),
#  Window(col_off=3904, row_off=18496, width=384, height=384),
#  Window(col_off=3904, row_off=18880, width=384, height=384),
#  Window(col_off=3904, row_off=19264, width=384, height=384),
#  Window(col_off=3904, row_off=19648, width=384, height=384),
#  Window(col_off=3904, row_off=20032, width=384, height=384),
#  Window(col_off=3904, row_off=20416, width=384, height=384),
#  Window(col_off=3904, row_off=20800, width=384, height=384),
#  Window(col_off=3904, row_off=21184, width=384, height=384),
#  Window(col_off=3904, row_off=21568, width=384, height=384),
#  Window(col_off=3904, row_off=21952, width=384, height=384),
#  Window(col_off=3904, row_off=22336, width=384, height=384),
#  Window(col_off=3904, row_off=22720, width=384, height=384),
#  Window(col_off=3904, row_off=23104, width=384, height=384),
#  Window(col_off=3904, row_off=23488, width=384, height=384),
#  Window(col_off=3904, row_off=23602, width=384, height=384),
#  Window(col_off=4288, row_off=64, width=384, height=384),
#  Window(col_off=4288, row_off=448, width=384, height=384),
#  Window(col_off=4288, row_off=832, width=384, height=384),
#  Window(col_off=4288, row_off=1216, width=384, height=384),
#  Window(col_off=4288, row_off=1600, width=384, height=384),
#  Window(col_off=4288, row_off=1984, width=384, height=384),
#  Window(col_off=4288, row_off=2368, width=384, height=384),
#  Window(col_off=4288, row_off=2752, width=384, height=384),
#  Window(col_off=4288, row_off=3136, width=384, height=384),
#  Window(col_off=4288, row_off=3520, width=384, height=384),
#  Window(col_off=4288, row_off=3904, width=384, height=384),
#  Window(col_off=4288, row_off=4288, width=384, height=384),
#  Window(col_off=4288, row_off=4672, width=384, height=384),
#  Window(col_off=4288, row_off=5056, width=384, height=384),
#  Window(col_off=4288, row_off=5440, width=384, height=384),
#  Window(col_off=4288, row_off=5824, width=384, height=384),
#  Window(col_off=4288, row_off=6208, width=384, height=384),
#  Window(col_off=4288, row_off=6592, width=384, height=384),
#  Window(col_off=4288, row_off=6976, width=384, height=384),
#  Window(col_off=4288, row_off=7360, width=384, height=384),
#  Window(col_off=4288, row_off=7744, width=384, height=384),
#  Window(col_off=4288, row_off=8128, width=384, height=384),
#  Window(col_off=4288, row_off=8512, width=384, height=384),
#  Window(col_off=4288, row_off=8896, width=384, height=384),
#  Window(col_off=4288, row_off=9280, width=384, height=384),
#  Window(col_off=4288, row_off=9664, width=384, height=384),
#  Window(col_off=4288, row_off=10048, width=384, height=384),
#  Window(col_off=4288, row_off=10432, width=384, height=384),
#  Window(col_off=4288, row_off=10816, width=384, height=384),
#  Window(col_off=4288, row_off=11200, width=384, height=384),
#  Window(col_off=4288, row_off=11584, width=384, height=384),
#  Window(col_off=4288, row_off=11968, width=384, height=384),
#  Window(col_off=4288, row_off=12352, width=384, height=384),
#  Window(col_off=4288, row_off=12736, width=384, height=384),
#  Window(col_off=4288, row_off=13120, width=384, height=384),
#  Window(col_off=4288, row_off=13504, width=384, height=384),
#  Window(col_off=4288, row_off=13888, width=384, height=384),
#  Window(col_off=4288, row_off=14272, width=384, height=384),
#  Window(col_off=4288, row_off=14656, width=384, height=384),
#  Window(col_off=4288, row_off=15040, width=384, height=384),
#  Window(col_off=4288, row_off=15424, width=384, height=384),
#  Window(col_off=4288, row_off=15808, width=384, height=384),
#  Window(col_off=4288, row_off=16192, width=384, height=384),
#  Window(col_off=4288, row_off=16576, width=384, height=384),
#  Window(col_off=4288, row_off=16960, width=384, height=384),
#  Window(col_off=4288, row_off=17344, width=384, height=384),
#  Window(col_off=4288, row_off=17728, width=384, height=384),
#  Window(col_off=4288, row_off=18112, width=384, height=384),
#  Window(col_off=4288, row_off=18496, width=384, height=384),
#  Window(col_off=4288, row_off=18880, width=384, height=384),
#  Window(col_off=4288, row_off=19264, width=384, height=384),
#  Window(col_off=4288, row_off=19648, width=384, height=384),
#  Window(col_off=4288, row_off=20032, width=384, height=384),
#  Window(col_off=4288, row_off=20416, width=384, height=384),
#  Window(col_off=4288, row_off=20800, width=384, height=384),
#  Window(col_off=4288, row_off=21184, width=384, height=384),
#  Window(col_off=4288, row_off=21568, width=384, height=384),
#  Window(col_off=4288, row_off=21952, width=384, height=384),
#  Window(col_off=4288, row_off=22336, width=384, height=384),
#  Window(col_off=4288, row_off=22720, width=384, height=384),
#  Window(col_off=4288, row_off=23104, width=384, height=384),
#  Window(col_off=4288, row_off=23488, width=384, height=384),
#  Window(col_off=4288, row_off=23602, width=384, height=384),
#  Window(col_off=4672, row_off=64, width=384, height=384),
#  Window(col_off=4672, row_off=448, width=384, height=384),
#  Window(col_off=4672, row_off=832, width=384, height=384),
#  Window(col_off=4672, row_off=1216, width=384, height=384),
#  Window(col_off=4672, row_off=1600, width=384, height=384),
#  Window(col_off=4672, row_off=1984, width=384, height=384),
#  Window(col_off=4672, row_off=2368, width=384, height=384),
#  Window(col_off=4672, row_off=2752, width=384, height=384),
#  Window(col_off=4672, row_off=3136, width=384, height=384),
#  Window(col_off=4672, row_off=3520, width=384, height=384),
#  Window(col_off=4672, row_off=3904, width=384, height=384),
#  Window(col_off=4672, row_off=4288, width=384, height=384),
#  Window(col_off=4672, row_off=4672, width=384, height=384),
#  Window(col_off=4672, row_off=5056, width=384, height=384),
#  Window(col_off=4672, row_off=5440, width=384, height=384),
#  Window(col_off=4672, row_off=5824, width=384, height=384),
#  Window(col_off=4672, row_off=6208, width=384, height=384),
#  Window(col_off=4672, row_off=6592, width=384, height=384),
#  Window(col_off=4672, row_off=6976, width=384, height=384),
#  Window(col_off=4672, row_off=7360, width=384, height=384),
#  Window(col_off=4672, row_off=7744, width=384, height=384),
#  Window(col_off=4672, row_off=8128, width=384, height=384),
#  Window(col_off=4672, row_off=8512, width=384, height=384),
#  Window(col_off=4672, row_off=8896, width=384, height=384),
#  Window(col_off=4672, row_off=9280, width=384, height=384),
#  Window(col_off=4672, row_off=9664, width=384, height=384),
#  Window(col_off=4672, row_off=10048, width=384, height=384),
#  Window(col_off=4672, row_off=10432, width=384, height=384),
#  Window(col_off=4672, row_off=10816, width=384, height=384),
#  Window(col_off=4672, row_off=11200, width=384, height=384),
#  Window(col_off=4672, row_off=11584, width=384, height=384),
#  Window(col_off=4672, row_off=11968, width=384, height=384),
#  Window(col_off=4672, row_off=12352, width=384, height=384),
#  Window(col_off=4672, row_off=12736, width=384, height=384),
#  Window(col_off=4672, row_off=13120, width=384, height=384),
#  Window(col_off=4672, row_off=13504, width=384, height=384),
#  Window(col_off=4672, row_off=13888, width=384, height=384),
#  Window(col_off=4672, row_off=14272, width=384, height=384),
#  Window(col_off=4672, row_off=14656, width=384, height=384),
#  Window(col_off=4672, row_off=15040, width=384, height=384),
#  Window(col_off=4672, row_off=15424, width=384, height=384),
#  Window(col_off=4672, row_off=15808, width=384, height=384),
#  Window(col_off=4672, row_off=16192, width=384, height=384),
#  Window(col_off=4672, row_off=16576, width=384, height=384),
#  Window(col_off=4672, row_off=16960, width=384, height=384),
#  Window(col_off=4672, row_off=17344, width=384, height=384),
#  Window(col_off=4672, row_off=17728, width=384, height=384),
#  Window(col_off=4672, row_off=18112, width=384, height=384),
#  Window(col_off=4672, row_off=18496, width=384, height=384),
#  Window(col_off=4672, row_off=18880, width=384, height=384),
#  Window(col_off=4672, row_off=19264, width=384, height=384),
#  Window(col_off=4672, row_off=19648, width=384, height=384),
#  Window(col_off=4672, row_off=20032, width=384, height=384),
#  Window(col_off=4672, row_off=20416, width=384, height=384),
#  Window(col_off=4672, row_off=20800, width=384, height=384),
#  Window(col_off=4672, row_off=21184, width=384, height=384),
#  Window(col_off=4672, row_off=21568, width=384, height=384),
#  Window(col_off=4672, row_off=21952, width=384, height=384),
#  Window(col_off=4672, row_off=22336, width=384, height=384),
#  Window(col_off=4672, row_off=22720, width=384, height=384),
#  Window(col_off=4672, row_off=23104, width=384, height=384),
#  Window(col_off=4672, row_off=23488, width=384, height=384),
#  Window(col_off=4672, row_off=23602, width=384, height=384),
#  Window(col_off=5056, row_off=64, width=384, height=384),
#  Window(col_off=5056, row_off=448, width=384, height=384),
#  Window(col_off=5056, row_off=832, width=384, height=384),
#  Window(col_off=5056, row_off=1216, width=384, height=384),
#  Window(col_off=5056, row_off=1600, width=384, height=384),
#  Window(col_off=5056, row_off=1984, width=384, height=384),
#  Window(col_off=5056, row_off=2368, width=384, height=384),
#  Window(col_off=5056, row_off=2752, width=384, height=384),
#  Window(col_off=5056, row_off=3136, width=384, height=384),
#  Window(col_off=5056, row_off=3520, width=384, height=384),
#  Window(col_off=5056, row_off=3904, width=384, height=384),
#  Window(col_off=5056, row_off=4288, width=384, height=384),
#  Window(col_off=5056, row_off=4672, width=384, height=384),
#  Window(col_off=5056, row_off=5056, width=384, height=384),
#  Window(col_off=5056, row_off=5440, width=384, height=384),
#  Window(col_off=5056, row_off=5824, width=384, height=384),
#  Window(col_off=5056, row_off=6208, width=384, height=384),
#  Window(col_off=5056, row_off=6592, width=384, height=384),
#  Window(col_off=5056, row_off=6976, width=384, height=384),
#  Window(col_off=5056, row_off=7360, width=384, height=384),
#  Window(col_off=5056, row_off=7744, width=384, height=384),
#  Window(col_off=5056, row_off=8128, width=384, height=384),
#  Window(col_off=5056, row_off=8512, width=384, height=384),
#  Window(col_off=5056, row_off=8896, width=384, height=384),
#  Window(col_off=5056, row_off=9280, width=384, height=384),
#  Window(col_off=5056, row_off=9664, width=384, height=384),
#  Window(col_off=5056, row_off=10048, width=384, height=384),
#  Window(col_off=5056, row_off=10432, width=384, height=384),
#  Window(col_off=5056, row_off=10816, width=384, height=384),
#  Window(col_off=5056, row_off=11200, width=384, height=384),
#  Window(col_off=5056, row_off=11584, width=384, height=384),
#  Window(col_off=5056, row_off=11968, width=384, height=384),
#  Window(col_off=5056, row_off=12352, width=384, height=384),
#  Window(col_off=5056, row_off=12736, width=384, height=384),
#  Window(col_off=5056, row_off=13120, width=384, height=384),
#  Window(col_off=5056, row_off=13504, width=384, height=384),
#  Window(col_off=5056, row_off=13888, width=384, height=384),
#  Window(col_off=5056, row_off=14272, width=384, height=384),
#  Window(col_off=5056, row_off=14656, width=384, height=384),
#  Window(col_off=5056, row_off=15040, width=384, height=384),
#  Window(col_off=5056, row_off=15424, width=384, height=384),
#  Window(col_off=5056, row_off=15808, width=384, height=384),
#  Window(col_off=5056, row_off=16192, width=384, height=384),
#  Window(col_off=5056, row_off=16576, width=384, height=384),
#  Window(col_off=5056, row_off=16960, width=384, height=384),
#  Window(col_off=5056, row_off=17344, width=384, height=384),
#  Window(col_off=5056, row_off=17728, width=384, height=384),
#  Window(col_off=5056, row_off=18112, width=384, height=384),
#  Window(col_off=5056, row_off=18496, width=384, height=384),
#  Window(col_off=5056, row_off=18880, width=384, height=384),
#  Window(col_off=5056, row_off=19264, width=384, height=384),
#  Window(col_off=5056, row_off=19648, width=384, height=384),
#  Window(col_off=5056, row_off=20032, width=384, height=384),
#  Window(col_off=5056, row_off=20416, width=384, height=384),
#  Window(col_off=5056, row_off=20800, width=384, height=384),
#  Window(col_off=5056, row_off=21184, width=384, height=384),
#  Window(col_off=5056, row_off=21568, width=384, height=384),
#  Window(col_off=5056, row_off=21952, width=384, height=384),
#  Window(col_off=5056, row_off=22336, width=384, height=384),
#  Window(col_off=5056, row_off=22720, width=384, height=384),
#  Window(col_off=5056, row_off=23104, width=384, height=384),
#  Window(col_off=5056, row_off=23488, width=384, height=384),
#  Window(col_off=5056, row_off=23602, width=384, height=384),
#  Window(col_off=5440, row_off=64, width=384, height=384),
#  Window(col_off=5440, row_off=448, width=384, height=384),
#  Window(col_off=5440, row_off=832, width=384, height=384),
#  Window(col_off=5440, row_off=1216, width=384, height=384),
#  Window(col_off=5440, row_off=1600, width=384, height=384),
#  Window(col_off=5440, row_off=1984, width=384, height=384),
#  Window(col_off=5440, row_off=2368, width=384, height=384),
#  Window(col_off=5440, row_off=2752, width=384, height=384),
#  Window(col_off=5440, row_off=3136, width=384, height=384),
#  Window(col_off=5440, row_off=3520, width=384, height=384),
#  Window(col_off=5440, row_off=3904, width=384, height=384),
#  Window(col_off=5440, row_off=4288, width=384, height=384),
#  Window(col_off=5440, row_off=4672, width=384, height=384),
#  Window(col_off=5440, row_off=5056, width=384, height=384),
#  Window(col_off=5440, row_off=5440, width=384, height=384),
#  Window(col_off=5440, row_off=5824, width=384, height=384),
#  Window(col_off=5440, row_off=6208, width=384, height=384),
#  Window(col_off=5440, row_off=6592, width=384, height=384),
#  Window(col_off=5440, row_off=6976, width=384, height=384),
#  Window(col_off=5440, row_off=7360, width=384, height=384),
#  Window(col_off=5440, row_off=7744, width=384, height=384),
#  Window(col_off=5440, row_off=8128, width=384, height=384),
#  Window(col_off=5440, row_off=8512, width=384, height=384),
#  Window(col_off=5440, row_off=8896, width=384, height=384),
#  Window(col_off=5440, row_off=9280, width=384, height=384),
#  Window(col_off=5440, row_off=9664, width=384, height=384),
#  Window(col_off=5440, row_off=10048, width=384, height=384),
#  Window(col_off=5440, row_off=10432, width=384, height=384),
#  Window(col_off=5440, row_off=10816, width=384, height=384),
#  Window(col_off=5440, row_off=11200, width=384, height=384),
#  Window(col_off=5440, row_off=11584, width=384, height=384),
#  Window(col_off=5440, row_off=11968, width=384, height=384),
#  Window(col_off=5440, row_off=12352, width=384, height=384),
#  Window(col_off=5440, row_off=12736, width=384, height=384),
#  Window(col_off=5440, row_off=13120, width=384, height=384),
#  Window(col_off=5440, row_off=13504, width=384, height=384),
#  Window(col_off=5440, row_off=13888, width=384, height=384),
#  Window(col_off=5440, row_off=14272, width=384, height=384),
#  Window(col_off=5440, row_off=14656, width=384, height=384),
#  Window(col_off=5440, row_off=15040, width=384, height=384),
#  Window(col_off=5440, row_off=15424, width=384, height=384),
#  Window(col_off=5440, row_off=15808, width=384, height=384),
#  Window(col_off=5440, row_off=16192, width=384, height=384),
#  Window(col_off=5440, row_off=16576, width=384, height=384),
#  Window(col_off=5440, row_off=16960, width=384, height=384),
#  Window(col_off=5440, row_off=17344, width=384, height=384),
#  Window(col_off=5440, row_off=17728, width=384, height=384),
#  Window(col_off=5440, row_off=18112, width=384, height=384),
#  Window(col_off=5440, row_off=18496, width=384, height=384),
#  Window(col_off=5440, row_off=18880, width=384, height=384),
#  Window(col_off=5440, row_off=19264, width=384, height=384),
#  Window(col_off=5440, row_off=19648, width=384, height=384),
#  Window(col_off=5440, row_off=20032, width=384, height=384),
#  Window(col_off=5440, row_off=20416, width=384, height=384),
#  Window(col_off=5440, row_off=20800, width=384, height=384),
#  Window(col_off=5440, row_off=21184, width=384, height=384),
#  Window(col_off=5440, row_off=21568, width=384, height=384),
#  Window(col_off=5440, row_off=21952, width=384, height=384),
#  Window(col_off=5440, row_off=22336, width=384, height=384),
#  Window(col_off=5440, row_off=22720, width=384, height=384),
#  Window(col_off=5440, row_off=23104, width=384, height=384),
#  Window(col_off=5440, row_off=23488, width=384, height=384),
#  Window(col_off=5440, row_off=23602, width=384, height=384),
#  Window(col_off=5824, row_off=64, width=384, height=384),
#  Window(col_off=5824, row_off=448, width=384, height=384),
#  Window(col_off=5824, row_off=832, width=384, height=384),
#  Window(col_off=5824, row_off=1216, width=384, height=384),
#  Window(col_off=5824, row_off=1600, width=384, height=384),
#  Window(col_off=5824, row_off=1984, width=384, height=384),
#  Window(col_off=5824, row_off=2368, width=384, height=384),
#  Window(col_off=5824, row_off=2752, width=384, height=384),
#  Window(col_off=5824, row_off=3136, width=384, height=384),
#  Window(col_off=5824, row_off=3520, width=384, height=384),
#  Window(col_off=5824, row_off=3904, width=384, height=384),
#  Window(col_off=5824, row_off=4288, width=384, height=384),
#  Window(col_off=5824, row_off=4672, width=384, height=384),
#  Window(col_off=5824, row_off=5056, width=384, height=384),
#  Window(col_off=5824, row_off=5440, width=384, height=384),
#  Window(col_off=5824, row_off=5824, width=384, height=384),
#  Window(col_off=5824, row_off=6208, width=384, height=384),
#  Window(col_off=5824, row_off=6592, width=384, height=384),
#  Window(col_off=5824, row_off=6976, width=384, height=384),
#  Window(col_off=5824, row_off=7360, width=384, height=384),
#  Window(col_off=5824, row_off=7744, width=384, height=384),
#  Window(col_off=5824, row_off=8128, width=384, height=384),
#  Window(col_off=5824, row_off=8512, width=384, height=384),
#  Window(col_off=5824, row_off=8896, width=384, height=384),
#  Window(col_off=5824, row_off=9280, width=384, height=384),
#  Window(col_off=5824, row_off=9664, width=384, height=384),
#  Window(col_off=5824, row_off=10048, width=384, height=384),
#  Window(col_off=5824, row_off=10432, width=384, height=384),
#  Window(col_off=5824, row_off=10816, width=384, height=384),
#  Window(col_off=5824, row_off=11200, width=384, height=384),
#  Window(col_off=5824, row_off=11584, width=384, height=384),
#  Window(col_off=5824, row_off=11968, width=384, height=384),
#  Window(col_off=5824, row_off=12352, width=384, height=384),
#  Window(col_off=5824, row_off=12736, width=384, height=384),
#  Window(col_off=5824, row_off=13120, width=384, height=384),
#  Window(col_off=5824, row_off=13504, width=384, height=384),
#  Window(col_off=5824, row_off=13888, width=384, height=384),
#  Window(col_off=5824, row_off=14272, width=384, height=384),
#  Window(col_off=5824, row_off=14656, width=384, height=384),
#  Window(col_off=5824, row_off=15040, width=384, height=384),
#  Window(col_off=5824, row_off=15424, width=384, height=384),
#  Window(col_off=5824, row_off=15808, width=384, height=384),
#  Window(col_off=5824, row_off=16192, width=384, height=384),
#  Window(col_off=5824, row_off=16576, width=384, height=384),
#  Window(col_off=5824, row_off=16960, width=384, height=384),
#  Window(col_off=5824, row_off=17344, width=384, height=384),
#  Window(col_off=5824, row_off=17728, width=384, height=384),
#  Window(col_off=5824, row_off=18112, width=384, height=384),
#  Window(col_off=5824, row_off=18496, width=384, height=384),
#  Window(col_off=5824, row_off=18880, width=384, height=384),
#  Window(col_off=5824, row_off=19264, width=384, height=384),
#  Window(col_off=5824, row_off=19648, width=384, height=384),
#  Window(col_off=5824, row_off=20032, width=384, height=384),
#  Window(col_off=5824, row_off=20416, width=384, height=384),
#  Window(col_off=5824, row_off=20800, width=384, height=384),
#  ...]

# %%
loader_args = {
    "batch_size": 1,
    "num_workers": 4,
    "pin_memory": True,
    "shuffle": False,
}
inference_loader = DataLoader(dataset, **loader_args)

# %%
# preferably use GPU
device = torch.device("cuda:2" if torch.cuda.is_available() else "cpu")
device_ids = [0]
# model with three input channels (RGB)
model = UNet(n_channels=3, n_classes=1, bilinear=True)
if torch.cuda.device_count() > 1:
    device_ids = [2]
model = nn.DataParallel(model, device_ids=device_ids)
model.load_state_dict(torch.load(os.path.join(checkpoint_dir, model_checkpoint)))
model = model.to(memory_format=torch.channels_last, device=device)

model.eval()
# Out:
# DataParallel(
#   (module): UNet(
#     (inc): DoubleConv(
#       (double_conv): Sequential(
#         (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU(inplace=True)
#       )
#     )
#     (down1): Down(
#       (maxpool_conv): Sequential(
#         (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (1): DoubleConv(
#           (double_conv): Sequential(
#             (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#             (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (5): ReLU(inplace=True)
#           )
#         )
#       )
#     )
#     (down2): Down(
#       (maxpool_conv): Sequential(
#         (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (1): DoubleConv(
#           (double_conv): Sequential(
#             (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#             (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (5): ReLU(inplace=True)
#           )
#         )
#       )
#     )
#     (down3): Down(
#       (maxpool_conv): Sequential(
#         (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (1): DoubleConv(
#           (double_conv): Sequential(
#             (0): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#             (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (5): ReLU(inplace=True)
#           )
#         )
#       )
#     )
#     (down4): Down(
#       (maxpool_conv): Sequential(
#         (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (1): DoubleConv(
#           (double_conv): Sequential(
#             (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#             (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (5): ReLU(inplace=True)
#           )
#         )
#       )
#     )
#     (up1): Up(
#       (up): Upsample(scale_factor=2.0, mode='bilinear')
#       (conv): DoubleConv(
#         (double_conv): Sequential(
#           (0): Conv2d(1024, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU(inplace=True)
#         )
#       )
#     )
#     (up2): Up(
#       (up): Upsample(scale_factor=2.0, mode='bilinear')
#       (conv): DoubleConv(
#         (double_conv): Sequential(
#           (0): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU(inplace=True)
#         )
#       )
#     )
#     (up3): Up(
#       (up): Upsample(scale_factor=2.0, mode='bilinear')
#       (conv): DoubleConv(
#         (double_conv): Sequential(
#           (0): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU(inplace=True)
#         )
#       )
#     )
#     (up4): Up(
#       (up): Upsample(scale_factor=2.0, mode='bilinear')
#       (conv): DoubleConv(
#         (double_conv): Sequential(
#           (0): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU(inplace=True)
#         )
#       )
#     )
#     (outc): OutConv(
#       (conv): Conv2d(64, 1, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
# )

# %%
if not os.path.exists(output_dir):
    os.makedirs(output_dir)
output_image_path = os.path.join(output_dir, filename)
output_image = rasterio.open(
    output_image_path,
    "w+",
    driver="GTiff",
    width=dataset.width,
    height=dataset.height,
    count=1,
    dtype=rasterio.uint8,
    crs=dataset.image_src.crs,
    transform=dataset.image_src.transform,
    compress="DEFLATE",
)


for images, cropped_windows in tqdm(inference_loader):
    images = images.to(device=device, memory_format=torch.channels_last)
    with torch.no_grad():
        output = model(images)
        output = torch.sigmoid(output)
        output = (output > 0.3).float()

        # crop tensor by dataset padding
        output = crop(
            output,
            top=dataset.padding,
            left=dataset.padding,
            height=dataset.tile_size - (2 * dataset.padding),
            width=dataset.tile_size - (2 * dataset.padding),
        )

        # add white edge to image of two pixels
        # output = torch.nn.functional.pad(output, (2, 2, 2, 2), value=2)

        output_image.write(
            output[0].cpu().numpy(),
            window=windows.Window(
                cropped_windows["col_off"].item(),
                cropped_windows["row_off"].item(),
                cropped_windows["width"].item(),
                cropped_windows["height"].item(),
            ),
        )
output_image.close()
# Out:
# 100%|██████████| 4158/4158 [01:01<00:00, 67.51it/s]
