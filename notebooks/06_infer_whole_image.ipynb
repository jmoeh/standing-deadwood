# %%
import os
import sys
import rasterio
import wandb
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from torchvision.transforms.functional import crop
from rasterio import windows
from tqdm import tqdm
from safetensors.torch import load_model
import numpy as np

# Add the parent directory to sys.path
sys.path.append(os.path.dirname(os.path.realpath(os.path.abspath(""))))

from unet.inference_dataset import DeadwoodInferenceDataset
from unet.unet_model import UNet
from unet.train_dataset import get_windows

# %%
inference_file = "/net/data_ssd/tree_mortality_orthophotos/orthophotos/spain_13_09_2023_east_granada_1_ortho.tif"

# %%
run_id = "cgv3wg89"
api = wandb.Api()
experiment = api.run(f"jmoehring/standing-deadwood-unet-pro/{run_id}")

# %%
fold: int = 1
epoch: int = 64

experiment_name = experiment.name.replace(f"_fold{fold}", "")
model_path = f"/net/home/jmoehring/experiments/{experiment_name}/fold_{fold}_epoch_{epoch}/model.safetensors"
output_dir = f"/net/scratch/jmoehring/inference/{experiment.name}"
filename = os.path.basename(inference_file)

# %%
dataset = DeadwoodInferenceDataset(inference_file, padding=256, tile_size=1024)

# %%
dataset.cropped_windows
# Out:
# [Window(col_off=256, row_off=256, width=512, height=512),
#  Window(col_off=256, row_off=768, width=512, height=512),
#  Window(col_off=256, row_off=1280, width=512, height=512),
#  Window(col_off=256, row_off=1792, width=512, height=512),
#  Window(col_off=256, row_off=2304, width=512, height=512),
#  Window(col_off=256, row_off=2816, width=512, height=512),
#  Window(col_off=256, row_off=3328, width=512, height=512),
#  Window(col_off=256, row_off=3840, width=512, height=512),
#  Window(col_off=256, row_off=4352, width=512, height=512),
#  Window(col_off=256, row_off=4864, width=512, height=512),
#  Window(col_off=256, row_off=5376, width=512, height=512),
#  Window(col_off=256, row_off=5888, width=512, height=512),
#  Window(col_off=256, row_off=6400, width=512, height=512),
#  Window(col_off=256, row_off=6912, width=512, height=512),
#  Window(col_off=256, row_off=7424, width=512, height=512),
#  Window(col_off=256, row_off=7936, width=512, height=512),
#  Window(col_off=256, row_off=8448, width=512, height=512),
#  Window(col_off=256, row_off=8960, width=512, height=512),
#  Window(col_off=256, row_off=9472, width=512, height=512),
#  Window(col_off=256, row_off=9984, width=512, height=512),
#  Window(col_off=256, row_off=10496, width=512, height=512),
#  Window(col_off=256, row_off=11008, width=512, height=512),
#  Window(col_off=256, row_off=11520, width=512, height=512),
#  Window(col_off=256, row_off=12032, width=512, height=512),
#  Window(col_off=256, row_off=12544, width=512, height=512),
#  Window(col_off=256, row_off=13056, width=512, height=512),
#  Window(col_off=256, row_off=13568, width=512, height=512),
#  Window(col_off=256, row_off=14080, width=512, height=512),
#  Window(col_off=256, row_off=14592, width=512, height=512),
#  Window(col_off=256, row_off=15104, width=512, height=512),
#  Window(col_off=256, row_off=15616, width=512, height=512),
#  Window(col_off=256, row_off=16128, width=512, height=512),
#  Window(col_off=256, row_off=16640, width=512, height=512),
#  Window(col_off=256, row_off=17152, width=512, height=512),
#  Window(col_off=256, row_off=17664, width=512, height=512),
#  Window(col_off=256, row_off=18176, width=512, height=512),
#  Window(col_off=256, row_off=18688, width=512, height=512),
#  Window(col_off=256, row_off=19200, width=512, height=512),
#  Window(col_off=256, row_off=19712, width=512, height=512),
#  Window(col_off=256, row_off=19910, width=512, height=512),
#  Window(col_off=768, row_off=256, width=512, height=512),
#  Window(col_off=768, row_off=768, width=512, height=512),
#  Window(col_off=768, row_off=1280, width=512, height=512),
#  Window(col_off=768, row_off=1792, width=512, height=512),
#  Window(col_off=768, row_off=2304, width=512, height=512),
#  Window(col_off=768, row_off=2816, width=512, height=512),
#  Window(col_off=768, row_off=3328, width=512, height=512),
#  Window(col_off=768, row_off=3840, width=512, height=512),
#  Window(col_off=768, row_off=4352, width=512, height=512),
#  Window(col_off=768, row_off=4864, width=512, height=512),
#  Window(col_off=768, row_off=5376, width=512, height=512),
#  Window(col_off=768, row_off=5888, width=512, height=512),
#  Window(col_off=768, row_off=6400, width=512, height=512),
#  Window(col_off=768, row_off=6912, width=512, height=512),
#  Window(col_off=768, row_off=7424, width=512, height=512),
#  Window(col_off=768, row_off=7936, width=512, height=512),
#  Window(col_off=768, row_off=8448, width=512, height=512),
#  Window(col_off=768, row_off=8960, width=512, height=512),
#  Window(col_off=768, row_off=9472, width=512, height=512),
#  Window(col_off=768, row_off=9984, width=512, height=512),
#  Window(col_off=768, row_off=10496, width=512, height=512),
#  Window(col_off=768, row_off=11008, width=512, height=512),
#  Window(col_off=768, row_off=11520, width=512, height=512),
#  Window(col_off=768, row_off=12032, width=512, height=512),
#  Window(col_off=768, row_off=12544, width=512, height=512),
#  Window(col_off=768, row_off=13056, width=512, height=512),
#  Window(col_off=768, row_off=13568, width=512, height=512),
#  Window(col_off=768, row_off=14080, width=512, height=512),
#  Window(col_off=768, row_off=14592, width=512, height=512),
#  Window(col_off=768, row_off=15104, width=512, height=512),
#  Window(col_off=768, row_off=15616, width=512, height=512),
#  Window(col_off=768, row_off=16128, width=512, height=512),
#  Window(col_off=768, row_off=16640, width=512, height=512),
#  Window(col_off=768, row_off=17152, width=512, height=512),
#  Window(col_off=768, row_off=17664, width=512, height=512),
#  Window(col_off=768, row_off=18176, width=512, height=512),
#  Window(col_off=768, row_off=18688, width=512, height=512),
#  Window(col_off=768, row_off=19200, width=512, height=512),
#  Window(col_off=768, row_off=19712, width=512, height=512),
#  Window(col_off=768, row_off=19910, width=512, height=512),
#  Window(col_off=1280, row_off=256, width=512, height=512),
#  Window(col_off=1280, row_off=768, width=512, height=512),
#  Window(col_off=1280, row_off=1280, width=512, height=512),
#  Window(col_off=1280, row_off=1792, width=512, height=512),
#  Window(col_off=1280, row_off=2304, width=512, height=512),
#  Window(col_off=1280, row_off=2816, width=512, height=512),
#  Window(col_off=1280, row_off=3328, width=512, height=512),
#  Window(col_off=1280, row_off=3840, width=512, height=512),
#  Window(col_off=1280, row_off=4352, width=512, height=512),
#  Window(col_off=1280, row_off=4864, width=512, height=512),
#  Window(col_off=1280, row_off=5376, width=512, height=512),
#  Window(col_off=1280, row_off=5888, width=512, height=512),
#  Window(col_off=1280, row_off=6400, width=512, height=512),
#  Window(col_off=1280, row_off=6912, width=512, height=512),
#  Window(col_off=1280, row_off=7424, width=512, height=512),
#  Window(col_off=1280, row_off=7936, width=512, height=512),
#  Window(col_off=1280, row_off=8448, width=512, height=512),
#  Window(col_off=1280, row_off=8960, width=512, height=512),
#  Window(col_off=1280, row_off=9472, width=512, height=512),
#  Window(col_off=1280, row_off=9984, width=512, height=512),
#  Window(col_off=1280, row_off=10496, width=512, height=512),
#  Window(col_off=1280, row_off=11008, width=512, height=512),
#  Window(col_off=1280, row_off=11520, width=512, height=512),
#  Window(col_off=1280, row_off=12032, width=512, height=512),
#  Window(col_off=1280, row_off=12544, width=512, height=512),
#  Window(col_off=1280, row_off=13056, width=512, height=512),
#  Window(col_off=1280, row_off=13568, width=512, height=512),
#  Window(col_off=1280, row_off=14080, width=512, height=512),
#  Window(col_off=1280, row_off=14592, width=512, height=512),
#  Window(col_off=1280, row_off=15104, width=512, height=512),
#  Window(col_off=1280, row_off=15616, width=512, height=512),
#  Window(col_off=1280, row_off=16128, width=512, height=512),
#  Window(col_off=1280, row_off=16640, width=512, height=512),
#  Window(col_off=1280, row_off=17152, width=512, height=512),
#  Window(col_off=1280, row_off=17664, width=512, height=512),
#  Window(col_off=1280, row_off=18176, width=512, height=512),
#  Window(col_off=1280, row_off=18688, width=512, height=512),
#  Window(col_off=1280, row_off=19200, width=512, height=512),
#  Window(col_off=1280, row_off=19712, width=512, height=512),
#  Window(col_off=1280, row_off=19910, width=512, height=512),
#  Window(col_off=1792, row_off=256, width=512, height=512),
#  Window(col_off=1792, row_off=768, width=512, height=512),
#  Window(col_off=1792, row_off=1280, width=512, height=512),
#  Window(col_off=1792, row_off=1792, width=512, height=512),
#  Window(col_off=1792, row_off=2304, width=512, height=512),
#  Window(col_off=1792, row_off=2816, width=512, height=512),
#  Window(col_off=1792, row_off=3328, width=512, height=512),
#  Window(col_off=1792, row_off=3840, width=512, height=512),
#  Window(col_off=1792, row_off=4352, width=512, height=512),
#  Window(col_off=1792, row_off=4864, width=512, height=512),
#  Window(col_off=1792, row_off=5376, width=512, height=512),
#  Window(col_off=1792, row_off=5888, width=512, height=512),
#  Window(col_off=1792, row_off=6400, width=512, height=512),
#  Window(col_off=1792, row_off=6912, width=512, height=512),
#  Window(col_off=1792, row_off=7424, width=512, height=512),
#  Window(col_off=1792, row_off=7936, width=512, height=512),
#  Window(col_off=1792, row_off=8448, width=512, height=512),
#  Window(col_off=1792, row_off=8960, width=512, height=512),
#  Window(col_off=1792, row_off=9472, width=512, height=512),
#  Window(col_off=1792, row_off=9984, width=512, height=512),
#  Window(col_off=1792, row_off=10496, width=512, height=512),
#  Window(col_off=1792, row_off=11008, width=512, height=512),
#  Window(col_off=1792, row_off=11520, width=512, height=512),
#  Window(col_off=1792, row_off=12032, width=512, height=512),
#  Window(col_off=1792, row_off=12544, width=512, height=512),
#  Window(col_off=1792, row_off=13056, width=512, height=512),
#  Window(col_off=1792, row_off=13568, width=512, height=512),
#  Window(col_off=1792, row_off=14080, width=512, height=512),
#  Window(col_off=1792, row_off=14592, width=512, height=512),
#  Window(col_off=1792, row_off=15104, width=512, height=512),
#  Window(col_off=1792, row_off=15616, width=512, height=512),
#  Window(col_off=1792, row_off=16128, width=512, height=512),
#  Window(col_off=1792, row_off=16640, width=512, height=512),
#  Window(col_off=1792, row_off=17152, width=512, height=512),
#  Window(col_off=1792, row_off=17664, width=512, height=512),
#  Window(col_off=1792, row_off=18176, width=512, height=512),
#  Window(col_off=1792, row_off=18688, width=512, height=512),
#  Window(col_off=1792, row_off=19200, width=512, height=512),
#  Window(col_off=1792, row_off=19712, width=512, height=512),
#  Window(col_off=1792, row_off=19910, width=512, height=512),
#  Window(col_off=2304, row_off=256, width=512, height=512),
#  Window(col_off=2304, row_off=768, width=512, height=512),
#  Window(col_off=2304, row_off=1280, width=512, height=512),
#  Window(col_off=2304, row_off=1792, width=512, height=512),
#  Window(col_off=2304, row_off=2304, width=512, height=512),
#  Window(col_off=2304, row_off=2816, width=512, height=512),
#  Window(col_off=2304, row_off=3328, width=512, height=512),
#  Window(col_off=2304, row_off=3840, width=512, height=512),
#  Window(col_off=2304, row_off=4352, width=512, height=512),
#  Window(col_off=2304, row_off=4864, width=512, height=512),
#  Window(col_off=2304, row_off=5376, width=512, height=512),
#  Window(col_off=2304, row_off=5888, width=512, height=512),
#  Window(col_off=2304, row_off=6400, width=512, height=512),
#  Window(col_off=2304, row_off=6912, width=512, height=512),
#  Window(col_off=2304, row_off=7424, width=512, height=512),
#  Window(col_off=2304, row_off=7936, width=512, height=512),
#  Window(col_off=2304, row_off=8448, width=512, height=512),
#  Window(col_off=2304, row_off=8960, width=512, height=512),
#  Window(col_off=2304, row_off=9472, width=512, height=512),
#  Window(col_off=2304, row_off=9984, width=512, height=512),
#  Window(col_off=2304, row_off=10496, width=512, height=512),
#  Window(col_off=2304, row_off=11008, width=512, height=512),
#  Window(col_off=2304, row_off=11520, width=512, height=512),
#  Window(col_off=2304, row_off=12032, width=512, height=512),
#  Window(col_off=2304, row_off=12544, width=512, height=512),
#  Window(col_off=2304, row_off=13056, width=512, height=512),
#  Window(col_off=2304, row_off=13568, width=512, height=512),
#  Window(col_off=2304, row_off=14080, width=512, height=512),
#  Window(col_off=2304, row_off=14592, width=512, height=512),
#  Window(col_off=2304, row_off=15104, width=512, height=512),
#  Window(col_off=2304, row_off=15616, width=512, height=512),
#  Window(col_off=2304, row_off=16128, width=512, height=512),
#  Window(col_off=2304, row_off=16640, width=512, height=512),
#  Window(col_off=2304, row_off=17152, width=512, height=512),
#  Window(col_off=2304, row_off=17664, width=512, height=512),
#  Window(col_off=2304, row_off=18176, width=512, height=512),
#  Window(col_off=2304, row_off=18688, width=512, height=512),
#  Window(col_off=2304, row_off=19200, width=512, height=512),
#  Window(col_off=2304, row_off=19712, width=512, height=512),
#  Window(col_off=2304, row_off=19910, width=512, height=512),
#  Window(col_off=2816, row_off=256, width=512, height=512),
#  Window(col_off=2816, row_off=768, width=512, height=512),
#  Window(col_off=2816, row_off=1280, width=512, height=512),
#  Window(col_off=2816, row_off=1792, width=512, height=512),
#  Window(col_off=2816, row_off=2304, width=512, height=512),
#  Window(col_off=2816, row_off=2816, width=512, height=512),
#  Window(col_off=2816, row_off=3328, width=512, height=512),
#  Window(col_off=2816, row_off=3840, width=512, height=512),
#  Window(col_off=2816, row_off=4352, width=512, height=512),
#  Window(col_off=2816, row_off=4864, width=512, height=512),
#  Window(col_off=2816, row_off=5376, width=512, height=512),
#  Window(col_off=2816, row_off=5888, width=512, height=512),
#  Window(col_off=2816, row_off=6400, width=512, height=512),
#  Window(col_off=2816, row_off=6912, width=512, height=512),
#  Window(col_off=2816, row_off=7424, width=512, height=512),
#  Window(col_off=2816, row_off=7936, width=512, height=512),
#  Window(col_off=2816, row_off=8448, width=512, height=512),
#  Window(col_off=2816, row_off=8960, width=512, height=512),
#  Window(col_off=2816, row_off=9472, width=512, height=512),
#  Window(col_off=2816, row_off=9984, width=512, height=512),
#  Window(col_off=2816, row_off=10496, width=512, height=512),
#  Window(col_off=2816, row_off=11008, width=512, height=512),
#  Window(col_off=2816, row_off=11520, width=512, height=512),
#  Window(col_off=2816, row_off=12032, width=512, height=512),
#  Window(col_off=2816, row_off=12544, width=512, height=512),
#  Window(col_off=2816, row_off=13056, width=512, height=512),
#  Window(col_off=2816, row_off=13568, width=512, height=512),
#  Window(col_off=2816, row_off=14080, width=512, height=512),
#  Window(col_off=2816, row_off=14592, width=512, height=512),
#  Window(col_off=2816, row_off=15104, width=512, height=512),
#  Window(col_off=2816, row_off=15616, width=512, height=512),
#  Window(col_off=2816, row_off=16128, width=512, height=512),
#  Window(col_off=2816, row_off=16640, width=512, height=512),
#  Window(col_off=2816, row_off=17152, width=512, height=512),
#  Window(col_off=2816, row_off=17664, width=512, height=512),
#  Window(col_off=2816, row_off=18176, width=512, height=512),
#  Window(col_off=2816, row_off=18688, width=512, height=512),
#  Window(col_off=2816, row_off=19200, width=512, height=512),
#  Window(col_off=2816, row_off=19712, width=512, height=512),
#  Window(col_off=2816, row_off=19910, width=512, height=512),
#  Window(col_off=3328, row_off=256, width=512, height=512),
#  Window(col_off=3328, row_off=768, width=512, height=512),
#  Window(col_off=3328, row_off=1280, width=512, height=512),
#  Window(col_off=3328, row_off=1792, width=512, height=512),
#  Window(col_off=3328, row_off=2304, width=512, height=512),
#  Window(col_off=3328, row_off=2816, width=512, height=512),
#  Window(col_off=3328, row_off=3328, width=512, height=512),
#  Window(col_off=3328, row_off=3840, width=512, height=512),
#  Window(col_off=3328, row_off=4352, width=512, height=512),
#  Window(col_off=3328, row_off=4864, width=512, height=512),
#  Window(col_off=3328, row_off=5376, width=512, height=512),
#  Window(col_off=3328, row_off=5888, width=512, height=512),
#  Window(col_off=3328, row_off=6400, width=512, height=512),
#  Window(col_off=3328, row_off=6912, width=512, height=512),
#  Window(col_off=3328, row_off=7424, width=512, height=512),
#  Window(col_off=3328, row_off=7936, width=512, height=512),
#  Window(col_off=3328, row_off=8448, width=512, height=512),
#  Window(col_off=3328, row_off=8960, width=512, height=512),
#  Window(col_off=3328, row_off=9472, width=512, height=512),
#  Window(col_off=3328, row_off=9984, width=512, height=512),
#  Window(col_off=3328, row_off=10496, width=512, height=512),
#  Window(col_off=3328, row_off=11008, width=512, height=512),
#  Window(col_off=3328, row_off=11520, width=512, height=512),
#  Window(col_off=3328, row_off=12032, width=512, height=512),
#  Window(col_off=3328, row_off=12544, width=512, height=512),
#  Window(col_off=3328, row_off=13056, width=512, height=512),
#  Window(col_off=3328, row_off=13568, width=512, height=512),
#  Window(col_off=3328, row_off=14080, width=512, height=512),
#  Window(col_off=3328, row_off=14592, width=512, height=512),
#  Window(col_off=3328, row_off=15104, width=512, height=512),
#  Window(col_off=3328, row_off=15616, width=512, height=512),
#  Window(col_off=3328, row_off=16128, width=512, height=512),
#  Window(col_off=3328, row_off=16640, width=512, height=512),
#  Window(col_off=3328, row_off=17152, width=512, height=512),
#  Window(col_off=3328, row_off=17664, width=512, height=512),
#  Window(col_off=3328, row_off=18176, width=512, height=512),
#  Window(col_off=3328, row_off=18688, width=512, height=512),
#  Window(col_off=3328, row_off=19200, width=512, height=512),
#  Window(col_off=3328, row_off=19712, width=512, height=512),
#  Window(col_off=3328, row_off=19910, width=512, height=512),
#  Window(col_off=3840, row_off=256, width=512, height=512),
#  Window(col_off=3840, row_off=768, width=512, height=512),
#  Window(col_off=3840, row_off=1280, width=512, height=512),
#  Window(col_off=3840, row_off=1792, width=512, height=512),
#  Window(col_off=3840, row_off=2304, width=512, height=512),
#  Window(col_off=3840, row_off=2816, width=512, height=512),
#  Window(col_off=3840, row_off=3328, width=512, height=512),
#  Window(col_off=3840, row_off=3840, width=512, height=512),
#  Window(col_off=3840, row_off=4352, width=512, height=512),
#  Window(col_off=3840, row_off=4864, width=512, height=512),
#  Window(col_off=3840, row_off=5376, width=512, height=512),
#  Window(col_off=3840, row_off=5888, width=512, height=512),
#  Window(col_off=3840, row_off=6400, width=512, height=512),
#  Window(col_off=3840, row_off=6912, width=512, height=512),
#  Window(col_off=3840, row_off=7424, width=512, height=512),
#  Window(col_off=3840, row_off=7936, width=512, height=512),
#  Window(col_off=3840, row_off=8448, width=512, height=512),
#  Window(col_off=3840, row_off=8960, width=512, height=512),
#  Window(col_off=3840, row_off=9472, width=512, height=512),
#  Window(col_off=3840, row_off=9984, width=512, height=512),
#  Window(col_off=3840, row_off=10496, width=512, height=512),
#  Window(col_off=3840, row_off=11008, width=512, height=512),
#  Window(col_off=3840, row_off=11520, width=512, height=512),
#  Window(col_off=3840, row_off=12032, width=512, height=512),
#  Window(col_off=3840, row_off=12544, width=512, height=512),
#  Window(col_off=3840, row_off=13056, width=512, height=512),
#  Window(col_off=3840, row_off=13568, width=512, height=512),
#  Window(col_off=3840, row_off=14080, width=512, height=512),
#  Window(col_off=3840, row_off=14592, width=512, height=512),
#  Window(col_off=3840, row_off=15104, width=512, height=512),
#  Window(col_off=3840, row_off=15616, width=512, height=512),
#  Window(col_off=3840, row_off=16128, width=512, height=512),
#  Window(col_off=3840, row_off=16640, width=512, height=512),
#  Window(col_off=3840, row_off=17152, width=512, height=512),
#  Window(col_off=3840, row_off=17664, width=512, height=512),
#  Window(col_off=3840, row_off=18176, width=512, height=512),
#  Window(col_off=3840, row_off=18688, width=512, height=512),
#  Window(col_off=3840, row_off=19200, width=512, height=512),
#  Window(col_off=3840, row_off=19712, width=512, height=512),
#  Window(col_off=3840, row_off=19910, width=512, height=512),
#  Window(col_off=4352, row_off=256, width=512, height=512),
#  Window(col_off=4352, row_off=768, width=512, height=512),
#  Window(col_off=4352, row_off=1280, width=512, height=512),
#  Window(col_off=4352, row_off=1792, width=512, height=512),
#  Window(col_off=4352, row_off=2304, width=512, height=512),
#  Window(col_off=4352, row_off=2816, width=512, height=512),
#  Window(col_off=4352, row_off=3328, width=512, height=512),
#  Window(col_off=4352, row_off=3840, width=512, height=512),
#  Window(col_off=4352, row_off=4352, width=512, height=512),
#  Window(col_off=4352, row_off=4864, width=512, height=512),
#  Window(col_off=4352, row_off=5376, width=512, height=512),
#  Window(col_off=4352, row_off=5888, width=512, height=512),
#  Window(col_off=4352, row_off=6400, width=512, height=512),
#  Window(col_off=4352, row_off=6912, width=512, height=512),
#  Window(col_off=4352, row_off=7424, width=512, height=512),
#  Window(col_off=4352, row_off=7936, width=512, height=512),
#  Window(col_off=4352, row_off=8448, width=512, height=512),
#  Window(col_off=4352, row_off=8960, width=512, height=512),
#  Window(col_off=4352, row_off=9472, width=512, height=512),
#  Window(col_off=4352, row_off=9984, width=512, height=512),
#  Window(col_off=4352, row_off=10496, width=512, height=512),
#  Window(col_off=4352, row_off=11008, width=512, height=512),
#  Window(col_off=4352, row_off=11520, width=512, height=512),
#  Window(col_off=4352, row_off=12032, width=512, height=512),
#  Window(col_off=4352, row_off=12544, width=512, height=512),
#  Window(col_off=4352, row_off=13056, width=512, height=512),
#  Window(col_off=4352, row_off=13568, width=512, height=512),
#  Window(col_off=4352, row_off=14080, width=512, height=512),
#  Window(col_off=4352, row_off=14592, width=512, height=512),
#  Window(col_off=4352, row_off=15104, width=512, height=512),
#  Window(col_off=4352, row_off=15616, width=512, height=512),
#  Window(col_off=4352, row_off=16128, width=512, height=512),
#  Window(col_off=4352, row_off=16640, width=512, height=512),
#  Window(col_off=4352, row_off=17152, width=512, height=512),
#  Window(col_off=4352, row_off=17664, width=512, height=512),
#  Window(col_off=4352, row_off=18176, width=512, height=512),
#  Window(col_off=4352, row_off=18688, width=512, height=512),
#  Window(col_off=4352, row_off=19200, width=512, height=512),
#  Window(col_off=4352, row_off=19712, width=512, height=512),
#  Window(col_off=4352, row_off=19910, width=512, height=512),
#  Window(col_off=4864, row_off=256, width=512, height=512),
#  Window(col_off=4864, row_off=768, width=512, height=512),
#  Window(col_off=4864, row_off=1280, width=512, height=512),
#  Window(col_off=4864, row_off=1792, width=512, height=512),
#  Window(col_off=4864, row_off=2304, width=512, height=512),
#  Window(col_off=4864, row_off=2816, width=512, height=512),
#  Window(col_off=4864, row_off=3328, width=512, height=512),
#  Window(col_off=4864, row_off=3840, width=512, height=512),
#  Window(col_off=4864, row_off=4352, width=512, height=512),
#  Window(col_off=4864, row_off=4864, width=512, height=512),
#  Window(col_off=4864, row_off=5376, width=512, height=512),
#  Window(col_off=4864, row_off=5888, width=512, height=512),
#  Window(col_off=4864, row_off=6400, width=512, height=512),
#  Window(col_off=4864, row_off=6912, width=512, height=512),
#  Window(col_off=4864, row_off=7424, width=512, height=512),
#  Window(col_off=4864, row_off=7936, width=512, height=512),
#  Window(col_off=4864, row_off=8448, width=512, height=512),
#  Window(col_off=4864, row_off=8960, width=512, height=512),
#  Window(col_off=4864, row_off=9472, width=512, height=512),
#  Window(col_off=4864, row_off=9984, width=512, height=512),
#  Window(col_off=4864, row_off=10496, width=512, height=512),
#  Window(col_off=4864, row_off=11008, width=512, height=512),
#  Window(col_off=4864, row_off=11520, width=512, height=512),
#  Window(col_off=4864, row_off=12032, width=512, height=512),
#  Window(col_off=4864, row_off=12544, width=512, height=512),
#  Window(col_off=4864, row_off=13056, width=512, height=512),
#  Window(col_off=4864, row_off=13568, width=512, height=512),
#  Window(col_off=4864, row_off=14080, width=512, height=512),
#  Window(col_off=4864, row_off=14592, width=512, height=512),
#  Window(col_off=4864, row_off=15104, width=512, height=512),
#  Window(col_off=4864, row_off=15616, width=512, height=512),
#  Window(col_off=4864, row_off=16128, width=512, height=512),
#  Window(col_off=4864, row_off=16640, width=512, height=512),
#  Window(col_off=4864, row_off=17152, width=512, height=512),
#  Window(col_off=4864, row_off=17664, width=512, height=512),
#  Window(col_off=4864, row_off=18176, width=512, height=512),
#  Window(col_off=4864, row_off=18688, width=512, height=512),
#  Window(col_off=4864, row_off=19200, width=512, height=512),
#  Window(col_off=4864, row_off=19712, width=512, height=512),
#  Window(col_off=4864, row_off=19910, width=512, height=512),
#  Window(col_off=5376, row_off=256, width=512, height=512),
#  Window(col_off=5376, row_off=768, width=512, height=512),
#  Window(col_off=5376, row_off=1280, width=512, height=512),
#  Window(col_off=5376, row_off=1792, width=512, height=512),
#  Window(col_off=5376, row_off=2304, width=512, height=512),
#  Window(col_off=5376, row_off=2816, width=512, height=512),
#  Window(col_off=5376, row_off=3328, width=512, height=512),
#  Window(col_off=5376, row_off=3840, width=512, height=512),
#  Window(col_off=5376, row_off=4352, width=512, height=512),
#  Window(col_off=5376, row_off=4864, width=512, height=512),
#  Window(col_off=5376, row_off=5376, width=512, height=512),
#  Window(col_off=5376, row_off=5888, width=512, height=512),
#  Window(col_off=5376, row_off=6400, width=512, height=512),
#  Window(col_off=5376, row_off=6912, width=512, height=512),
#  Window(col_off=5376, row_off=7424, width=512, height=512),
#  Window(col_off=5376, row_off=7936, width=512, height=512),
#  Window(col_off=5376, row_off=8448, width=512, height=512),
#  Window(col_off=5376, row_off=8960, width=512, height=512),
#  Window(col_off=5376, row_off=9472, width=512, height=512),
#  Window(col_off=5376, row_off=9984, width=512, height=512),
#  Window(col_off=5376, row_off=10496, width=512, height=512),
#  Window(col_off=5376, row_off=11008, width=512, height=512),
#  Window(col_off=5376, row_off=11520, width=512, height=512),
#  Window(col_off=5376, row_off=12032, width=512, height=512),
#  Window(col_off=5376, row_off=12544, width=512, height=512),
#  Window(col_off=5376, row_off=13056, width=512, height=512),
#  Window(col_off=5376, row_off=13568, width=512, height=512),
#  Window(col_off=5376, row_off=14080, width=512, height=512),
#  Window(col_off=5376, row_off=14592, width=512, height=512),
#  Window(col_off=5376, row_off=15104, width=512, height=512),
#  Window(col_off=5376, row_off=15616, width=512, height=512),
#  Window(col_off=5376, row_off=16128, width=512, height=512),
#  Window(col_off=5376, row_off=16640, width=512, height=512),
#  Window(col_off=5376, row_off=17152, width=512, height=512),
#  Window(col_off=5376, row_off=17664, width=512, height=512),
#  Window(col_off=5376, row_off=18176, width=512, height=512),
#  Window(col_off=5376, row_off=18688, width=512, height=512),
#  Window(col_off=5376, row_off=19200, width=512, height=512),
#  Window(col_off=5376, row_off=19712, width=512, height=512),
#  Window(col_off=5376, row_off=19910, width=512, height=512),
#  Window(col_off=5888, row_off=256, width=512, height=512),
#  Window(col_off=5888, row_off=768, width=512, height=512),
#  Window(col_off=5888, row_off=1280, width=512, height=512),
#  Window(col_off=5888, row_off=1792, width=512, height=512),
#  Window(col_off=5888, row_off=2304, width=512, height=512),
#  Window(col_off=5888, row_off=2816, width=512, height=512),
#  Window(col_off=5888, row_off=3328, width=512, height=512),
#  Window(col_off=5888, row_off=3840, width=512, height=512),
#  Window(col_off=5888, row_off=4352, width=512, height=512),
#  Window(col_off=5888, row_off=4864, width=512, height=512),
#  Window(col_off=5888, row_off=5376, width=512, height=512),
#  Window(col_off=5888, row_off=5888, width=512, height=512),
#  Window(col_off=5888, row_off=6400, width=512, height=512),
#  Window(col_off=5888, row_off=6912, width=512, height=512),
#  Window(col_off=5888, row_off=7424, width=512, height=512),
#  Window(col_off=5888, row_off=7936, width=512, height=512),
#  Window(col_off=5888, row_off=8448, width=512, height=512),
#  Window(col_off=5888, row_off=8960, width=512, height=512),
#  Window(col_off=5888, row_off=9472, width=512, height=512),
#  Window(col_off=5888, row_off=9984, width=512, height=512),
#  Window(col_off=5888, row_off=10496, width=512, height=512),
#  Window(col_off=5888, row_off=11008, width=512, height=512),
#  Window(col_off=5888, row_off=11520, width=512, height=512),
#  Window(col_off=5888, row_off=12032, width=512, height=512),
#  Window(col_off=5888, row_off=12544, width=512, height=512),
#  Window(col_off=5888, row_off=13056, width=512, height=512),
#  Window(col_off=5888, row_off=13568, width=512, height=512),
#  Window(col_off=5888, row_off=14080, width=512, height=512),
#  Window(col_off=5888, row_off=14592, width=512, height=512),
#  Window(col_off=5888, row_off=15104, width=512, height=512),
#  Window(col_off=5888, row_off=15616, width=512, height=512),
#  Window(col_off=5888, row_off=16128, width=512, height=512),
#  Window(col_off=5888, row_off=16640, width=512, height=512),
#  Window(col_off=5888, row_off=17152, width=512, height=512),
#  Window(col_off=5888, row_off=17664, width=512, height=512),
#  Window(col_off=5888, row_off=18176, width=512, height=512),
#  Window(col_off=5888, row_off=18688, width=512, height=512),
#  Window(col_off=5888, row_off=19200, width=512, height=512),
#  Window(col_off=5888, row_off=19712, width=512, height=512),
#  Window(col_off=5888, row_off=19910, width=512, height=512),
#  Window(col_off=6400, row_off=256, width=512, height=512),
#  Window(col_off=6400, row_off=768, width=512, height=512),
#  Window(col_off=6400, row_off=1280, width=512, height=512),
#  Window(col_off=6400, row_off=1792, width=512, height=512),
#  Window(col_off=6400, row_off=2304, width=512, height=512),
#  Window(col_off=6400, row_off=2816, width=512, height=512),
#  Window(col_off=6400, row_off=3328, width=512, height=512),
#  Window(col_off=6400, row_off=3840, width=512, height=512),
#  Window(col_off=6400, row_off=4352, width=512, height=512),
#  Window(col_off=6400, row_off=4864, width=512, height=512),
#  Window(col_off=6400, row_off=5376, width=512, height=512),
#  Window(col_off=6400, row_off=5888, width=512, height=512),
#  Window(col_off=6400, row_off=6400, width=512, height=512),
#  Window(col_off=6400, row_off=6912, width=512, height=512),
#  Window(col_off=6400, row_off=7424, width=512, height=512),
#  Window(col_off=6400, row_off=7936, width=512, height=512),
#  Window(col_off=6400, row_off=8448, width=512, height=512),
#  Window(col_off=6400, row_off=8960, width=512, height=512),
#  Window(col_off=6400, row_off=9472, width=512, height=512),
#  Window(col_off=6400, row_off=9984, width=512, height=512),
#  Window(col_off=6400, row_off=10496, width=512, height=512),
#  Window(col_off=6400, row_off=11008, width=512, height=512),
#  Window(col_off=6400, row_off=11520, width=512, height=512),
#  Window(col_off=6400, row_off=12032, width=512, height=512),
#  Window(col_off=6400, row_off=12544, width=512, height=512),
#  Window(col_off=6400, row_off=13056, width=512, height=512),
#  Window(col_off=6400, row_off=13568, width=512, height=512),
#  Window(col_off=6400, row_off=14080, width=512, height=512),
#  Window(col_off=6400, row_off=14592, width=512, height=512),
#  Window(col_off=6400, row_off=15104, width=512, height=512),
#  Window(col_off=6400, row_off=15616, width=512, height=512),
#  Window(col_off=6400, row_off=16128, width=512, height=512),
#  Window(col_off=6400, row_off=16640, width=512, height=512),
#  Window(col_off=6400, row_off=17152, width=512, height=512),
#  Window(col_off=6400, row_off=17664, width=512, height=512),
#  Window(col_off=6400, row_off=18176, width=512, height=512),
#  Window(col_off=6400, row_off=18688, width=512, height=512),
#  Window(col_off=6400, row_off=19200, width=512, height=512),
#  Window(col_off=6400, row_off=19712, width=512, height=512),
#  Window(col_off=6400, row_off=19910, width=512, height=512),
#  Window(col_off=6912, row_off=256, width=512, height=512),
#  Window(col_off=6912, row_off=768, width=512, height=512),
#  Window(col_off=6912, row_off=1280, width=512, height=512),
#  Window(col_off=6912, row_off=1792, width=512, height=512),
#  Window(col_off=6912, row_off=2304, width=512, height=512),
#  Window(col_off=6912, row_off=2816, width=512, height=512),
#  Window(col_off=6912, row_off=3328, width=512, height=512),
#  Window(col_off=6912, row_off=3840, width=512, height=512),
#  Window(col_off=6912, row_off=4352, width=512, height=512),
#  Window(col_off=6912, row_off=4864, width=512, height=512),
#  Window(col_off=6912, row_off=5376, width=512, height=512),
#  Window(col_off=6912, row_off=5888, width=512, height=512),
#  Window(col_off=6912, row_off=6400, width=512, height=512),
#  Window(col_off=6912, row_off=6912, width=512, height=512),
#  Window(col_off=6912, row_off=7424, width=512, height=512),
#  Window(col_off=6912, row_off=7936, width=512, height=512),
#  Window(col_off=6912, row_off=8448, width=512, height=512),
#  Window(col_off=6912, row_off=8960, width=512, height=512),
#  Window(col_off=6912, row_off=9472, width=512, height=512),
#  Window(col_off=6912, row_off=9984, width=512, height=512),
#  Window(col_off=6912, row_off=10496, width=512, height=512),
#  Window(col_off=6912, row_off=11008, width=512, height=512),
#  Window(col_off=6912, row_off=11520, width=512, height=512),
#  Window(col_off=6912, row_off=12032, width=512, height=512),
#  Window(col_off=6912, row_off=12544, width=512, height=512),
#  Window(col_off=6912, row_off=13056, width=512, height=512),
#  Window(col_off=6912, row_off=13568, width=512, height=512),
#  Window(col_off=6912, row_off=14080, width=512, height=512),
#  Window(col_off=6912, row_off=14592, width=512, height=512),
#  Window(col_off=6912, row_off=15104, width=512, height=512),
#  Window(col_off=6912, row_off=15616, width=512, height=512),
#  Window(col_off=6912, row_off=16128, width=512, height=512),
#  Window(col_off=6912, row_off=16640, width=512, height=512),
#  Window(col_off=6912, row_off=17152, width=512, height=512),
#  Window(col_off=6912, row_off=17664, width=512, height=512),
#  Window(col_off=6912, row_off=18176, width=512, height=512),
#  Window(col_off=6912, row_off=18688, width=512, height=512),
#  Window(col_off=6912, row_off=19200, width=512, height=512),
#  Window(col_off=6912, row_off=19712, width=512, height=512),
#  Window(col_off=6912, row_off=19910, width=512, height=512),
#  Window(col_off=7424, row_off=256, width=512, height=512),
#  Window(col_off=7424, row_off=768, width=512, height=512),
#  Window(col_off=7424, row_off=1280, width=512, height=512),
#  Window(col_off=7424, row_off=1792, width=512, height=512),
#  Window(col_off=7424, row_off=2304, width=512, height=512),
#  Window(col_off=7424, row_off=2816, width=512, height=512),
#  Window(col_off=7424, row_off=3328, width=512, height=512),
#  Window(col_off=7424, row_off=3840, width=512, height=512),
#  Window(col_off=7424, row_off=4352, width=512, height=512),
#  Window(col_off=7424, row_off=4864, width=512, height=512),
#  Window(col_off=7424, row_off=5376, width=512, height=512),
#  Window(col_off=7424, row_off=5888, width=512, height=512),
#  Window(col_off=7424, row_off=6400, width=512, height=512),
#  Window(col_off=7424, row_off=6912, width=512, height=512),
#  Window(col_off=7424, row_off=7424, width=512, height=512),
#  Window(col_off=7424, row_off=7936, width=512, height=512),
#  Window(col_off=7424, row_off=8448, width=512, height=512),
#  Window(col_off=7424, row_off=8960, width=512, height=512),
#  Window(col_off=7424, row_off=9472, width=512, height=512),
#  Window(col_off=7424, row_off=9984, width=512, height=512),
#  Window(col_off=7424, row_off=10496, width=512, height=512),
#  Window(col_off=7424, row_off=11008, width=512, height=512),
#  Window(col_off=7424, row_off=11520, width=512, height=512),
#  Window(col_off=7424, row_off=12032, width=512, height=512),
#  Window(col_off=7424, row_off=12544, width=512, height=512),
#  Window(col_off=7424, row_off=13056, width=512, height=512),
#  Window(col_off=7424, row_off=13568, width=512, height=512),
#  Window(col_off=7424, row_off=14080, width=512, height=512),
#  Window(col_off=7424, row_off=14592, width=512, height=512),
#  Window(col_off=7424, row_off=15104, width=512, height=512),
#  Window(col_off=7424, row_off=15616, width=512, height=512),
#  Window(col_off=7424, row_off=16128, width=512, height=512),
#  Window(col_off=7424, row_off=16640, width=512, height=512),
#  Window(col_off=7424, row_off=17152, width=512, height=512),
#  Window(col_off=7424, row_off=17664, width=512, height=512),
#  Window(col_off=7424, row_off=18176, width=512, height=512),
#  Window(col_off=7424, row_off=18688, width=512, height=512),
#  Window(col_off=7424, row_off=19200, width=512, height=512),
#  Window(col_off=7424, row_off=19712, width=512, height=512),
#  Window(col_off=7424, row_off=19910, width=512, height=512),
#  Window(col_off=7936, row_off=256, width=512, height=512),
#  Window(col_off=7936, row_off=768, width=512, height=512),
#  Window(col_off=7936, row_off=1280, width=512, height=512),
#  Window(col_off=7936, row_off=1792, width=512, height=512),
#  Window(col_off=7936, row_off=2304, width=512, height=512),
#  Window(col_off=7936, row_off=2816, width=512, height=512),
#  Window(col_off=7936, row_off=3328, width=512, height=512),
#  Window(col_off=7936, row_off=3840, width=512, height=512),
#  Window(col_off=7936, row_off=4352, width=512, height=512),
#  Window(col_off=7936, row_off=4864, width=512, height=512),
#  Window(col_off=7936, row_off=5376, width=512, height=512),
#  Window(col_off=7936, row_off=5888, width=512, height=512),
#  Window(col_off=7936, row_off=6400, width=512, height=512),
#  Window(col_off=7936, row_off=6912, width=512, height=512),
#  Window(col_off=7936, row_off=7424, width=512, height=512),
#  Window(col_off=7936, row_off=7936, width=512, height=512),
#  Window(col_off=7936, row_off=8448, width=512, height=512),
#  Window(col_off=7936, row_off=8960, width=512, height=512),
#  Window(col_off=7936, row_off=9472, width=512, height=512),
#  Window(col_off=7936, row_off=9984, width=512, height=512),
#  Window(col_off=7936, row_off=10496, width=512, height=512),
#  Window(col_off=7936, row_off=11008, width=512, height=512),
#  Window(col_off=7936, row_off=11520, width=512, height=512),
#  Window(col_off=7936, row_off=12032, width=512, height=512),
#  Window(col_off=7936, row_off=12544, width=512, height=512),
#  Window(col_off=7936, row_off=13056, width=512, height=512),
#  Window(col_off=7936, row_off=13568, width=512, height=512),
#  Window(col_off=7936, row_off=14080, width=512, height=512),
#  Window(col_off=7936, row_off=14592, width=512, height=512),
#  Window(col_off=7936, row_off=15104, width=512, height=512),
#  Window(col_off=7936, row_off=15616, width=512, height=512),
#  Window(col_off=7936, row_off=16128, width=512, height=512),
#  Window(col_off=7936, row_off=16640, width=512, height=512),
#  Window(col_off=7936, row_off=17152, width=512, height=512),
#  Window(col_off=7936, row_off=17664, width=512, height=512),
#  Window(col_off=7936, row_off=18176, width=512, height=512),
#  Window(col_off=7936, row_off=18688, width=512, height=512),
#  Window(col_off=7936, row_off=19200, width=512, height=512),
#  Window(col_off=7936, row_off=19712, width=512, height=512),
#  Window(col_off=7936, row_off=19910, width=512, height=512),
#  Window(col_off=8448, row_off=256, width=512, height=512),
#  Window(col_off=8448, row_off=768, width=512, height=512),
#  Window(col_off=8448, row_off=1280, width=512, height=512),
#  Window(col_off=8448, row_off=1792, width=512, height=512),
#  Window(col_off=8448, row_off=2304, width=512, height=512),
#  Window(col_off=8448, row_off=2816, width=512, height=512),
#  Window(col_off=8448, row_off=3328, width=512, height=512),
#  Window(col_off=8448, row_off=3840, width=512, height=512),
#  Window(col_off=8448, row_off=4352, width=512, height=512),
#  Window(col_off=8448, row_off=4864, width=512, height=512),
#  Window(col_off=8448, row_off=5376, width=512, height=512),
#  Window(col_off=8448, row_off=5888, width=512, height=512),
#  Window(col_off=8448, row_off=6400, width=512, height=512),
#  Window(col_off=8448, row_off=6912, width=512, height=512),
#  Window(col_off=8448, row_off=7424, width=512, height=512),
#  Window(col_off=8448, row_off=7936, width=512, height=512),
#  Window(col_off=8448, row_off=8448, width=512, height=512),
#  Window(col_off=8448, row_off=8960, width=512, height=512),
#  Window(col_off=8448, row_off=9472, width=512, height=512),
#  Window(col_off=8448, row_off=9984, width=512, height=512),
#  Window(col_off=8448, row_off=10496, width=512, height=512),
#  Window(col_off=8448, row_off=11008, width=512, height=512),
#  Window(col_off=8448, row_off=11520, width=512, height=512),
#  Window(col_off=8448, row_off=12032, width=512, height=512),
#  Window(col_off=8448, row_off=12544, width=512, height=512),
#  Window(col_off=8448, row_off=13056, width=512, height=512),
#  Window(col_off=8448, row_off=13568, width=512, height=512),
#  Window(col_off=8448, row_off=14080, width=512, height=512),
#  Window(col_off=8448, row_off=14592, width=512, height=512),
#  Window(col_off=8448, row_off=15104, width=512, height=512),
#  Window(col_off=8448, row_off=15616, width=512, height=512),
#  Window(col_off=8448, row_off=16128, width=512, height=512),
#  Window(col_off=8448, row_off=16640, width=512, height=512),
#  Window(col_off=8448, row_off=17152, width=512, height=512),
#  Window(col_off=8448, row_off=17664, width=512, height=512),
#  Window(col_off=8448, row_off=18176, width=512, height=512),
#  Window(col_off=8448, row_off=18688, width=512, height=512),
#  Window(col_off=8448, row_off=19200, width=512, height=512),
#  Window(col_off=8448, row_off=19712, width=512, height=512),
#  Window(col_off=8448, row_off=19910, width=512, height=512),
#  Window(col_off=8960, row_off=256, width=512, height=512),
#  Window(col_off=8960, row_off=768, width=512, height=512),
#  Window(col_off=8960, row_off=1280, width=512, height=512),
#  Window(col_off=8960, row_off=1792, width=512, height=512),
#  Window(col_off=8960, row_off=2304, width=512, height=512),
#  Window(col_off=8960, row_off=2816, width=512, height=512),
#  Window(col_off=8960, row_off=3328, width=512, height=512),
#  Window(col_off=8960, row_off=3840, width=512, height=512),
#  Window(col_off=8960, row_off=4352, width=512, height=512),
#  Window(col_off=8960, row_off=4864, width=512, height=512),
#  Window(col_off=8960, row_off=5376, width=512, height=512),
#  Window(col_off=8960, row_off=5888, width=512, height=512),
#  Window(col_off=8960, row_off=6400, width=512, height=512),
#  Window(col_off=8960, row_off=6912, width=512, height=512),
#  Window(col_off=8960, row_off=7424, width=512, height=512),
#  Window(col_off=8960, row_off=7936, width=512, height=512),
#  Window(col_off=8960, row_off=8448, width=512, height=512),
#  Window(col_off=8960, row_off=8960, width=512, height=512),
#  Window(col_off=8960, row_off=9472, width=512, height=512),
#  Window(col_off=8960, row_off=9984, width=512, height=512),
#  Window(col_off=8960, row_off=10496, width=512, height=512),
#  Window(col_off=8960, row_off=11008, width=512, height=512),
#  Window(col_off=8960, row_off=11520, width=512, height=512),
#  Window(col_off=8960, row_off=12032, width=512, height=512),
#  Window(col_off=8960, row_off=12544, width=512, height=512),
#  Window(col_off=8960, row_off=13056, width=512, height=512),
#  Window(col_off=8960, row_off=13568, width=512, height=512),
#  Window(col_off=8960, row_off=14080, width=512, height=512),
#  Window(col_off=8960, row_off=14592, width=512, height=512),
#  Window(col_off=8960, row_off=15104, width=512, height=512),
#  Window(col_off=8960, row_off=15616, width=512, height=512),
#  Window(col_off=8960, row_off=16128, width=512, height=512),
#  Window(col_off=8960, row_off=16640, width=512, height=512),
#  Window(col_off=8960, row_off=17152, width=512, height=512),
#  Window(col_off=8960, row_off=17664, width=512, height=512),
#  Window(col_off=8960, row_off=18176, width=512, height=512),
#  Window(col_off=8960, row_off=18688, width=512, height=512),
#  Window(col_off=8960, row_off=19200, width=512, height=512),
#  Window(col_off=8960, row_off=19712, width=512, height=512),
#  Window(col_off=8960, row_off=19910, width=512, height=512),
#  Window(col_off=9472, row_off=256, width=512, height=512),
#  Window(col_off=9472, row_off=768, width=512, height=512),
#  Window(col_off=9472, row_off=1280, width=512, height=512),
#  Window(col_off=9472, row_off=1792, width=512, height=512),
#  Window(col_off=9472, row_off=2304, width=512, height=512),
#  Window(col_off=9472, row_off=2816, width=512, height=512),
#  Window(col_off=9472, row_off=3328, width=512, height=512),
#  Window(col_off=9472, row_off=3840, width=512, height=512),
#  Window(col_off=9472, row_off=4352, width=512, height=512),
#  Window(col_off=9472, row_off=4864, width=512, height=512),
#  Window(col_off=9472, row_off=5376, width=512, height=512),
#  Window(col_off=9472, row_off=5888, width=512, height=512),
#  Window(col_off=9472, row_off=6400, width=512, height=512),
#  Window(col_off=9472, row_off=6912, width=512, height=512),
#  Window(col_off=9472, row_off=7424, width=512, height=512),
#  Window(col_off=9472, row_off=7936, width=512, height=512),
#  Window(col_off=9472, row_off=8448, width=512, height=512),
#  Window(col_off=9472, row_off=8960, width=512, height=512),
#  Window(col_off=9472, row_off=9472, width=512, height=512),
#  Window(col_off=9472, row_off=9984, width=512, height=512),
#  Window(col_off=9472, row_off=10496, width=512, height=512),
#  Window(col_off=9472, row_off=11008, width=512, height=512),
#  Window(col_off=9472, row_off=11520, width=512, height=512),
#  Window(col_off=9472, row_off=12032, width=512, height=512),
#  Window(col_off=9472, row_off=12544, width=512, height=512),
#  Window(col_off=9472, row_off=13056, width=512, height=512),
#  Window(col_off=9472, row_off=13568, width=512, height=512),
#  Window(col_off=9472, row_off=14080, width=512, height=512),
#  Window(col_off=9472, row_off=14592, width=512, height=512),
#  Window(col_off=9472, row_off=15104, width=512, height=512),
#  Window(col_off=9472, row_off=15616, width=512, height=512),
#  Window(col_off=9472, row_off=16128, width=512, height=512),
#  Window(col_off=9472, row_off=16640, width=512, height=512),
#  Window(col_off=9472, row_off=17152, width=512, height=512),
#  Window(col_off=9472, row_off=17664, width=512, height=512),
#  Window(col_off=9472, row_off=18176, width=512, height=512),
#  Window(col_off=9472, row_off=18688, width=512, height=512),
#  Window(col_off=9472, row_off=19200, width=512, height=512),
#  Window(col_off=9472, row_off=19712, width=512, height=512),
#  Window(col_off=9472, row_off=19910, width=512, height=512),
#  Window(col_off=9984, row_off=256, width=512, height=512),
#  Window(col_off=9984, row_off=768, width=512, height=512),
#  Window(col_off=9984, row_off=1280, width=512, height=512),
#  Window(col_off=9984, row_off=1792, width=512, height=512),
#  Window(col_off=9984, row_off=2304, width=512, height=512),
#  Window(col_off=9984, row_off=2816, width=512, height=512),
#  Window(col_off=9984, row_off=3328, width=512, height=512),
#  Window(col_off=9984, row_off=3840, width=512, height=512),
#  Window(col_off=9984, row_off=4352, width=512, height=512),
#  Window(col_off=9984, row_off=4864, width=512, height=512),
#  Window(col_off=9984, row_off=5376, width=512, height=512),
#  Window(col_off=9984, row_off=5888, width=512, height=512),
#  Window(col_off=9984, row_off=6400, width=512, height=512),
#  Window(col_off=9984, row_off=6912, width=512, height=512),
#  Window(col_off=9984, row_off=7424, width=512, height=512),
#  Window(col_off=9984, row_off=7936, width=512, height=512),
#  Window(col_off=9984, row_off=8448, width=512, height=512),
#  Window(col_off=9984, row_off=8960, width=512, height=512),
#  Window(col_off=9984, row_off=9472, width=512, height=512),
#  Window(col_off=9984, row_off=9984, width=512, height=512),
#  Window(col_off=9984, row_off=10496, width=512, height=512),
#  Window(col_off=9984, row_off=11008, width=512, height=512),
#  Window(col_off=9984, row_off=11520, width=512, height=512),
#  Window(col_off=9984, row_off=12032, width=512, height=512),
#  Window(col_off=9984, row_off=12544, width=512, height=512),
#  Window(col_off=9984, row_off=13056, width=512, height=512),
#  Window(col_off=9984, row_off=13568, width=512, height=512),
#  Window(col_off=9984, row_off=14080, width=512, height=512),
#  Window(col_off=9984, row_off=14592, width=512, height=512),
#  Window(col_off=9984, row_off=15104, width=512, height=512),
#  Window(col_off=9984, row_off=15616, width=512, height=512),
#  Window(col_off=9984, row_off=16128, width=512, height=512),
#  Window(col_off=9984, row_off=16640, width=512, height=512),
#  Window(col_off=9984, row_off=17152, width=512, height=512),
#  Window(col_off=9984, row_off=17664, width=512, height=512),
#  Window(col_off=9984, row_off=18176, width=512, height=512),
#  Window(col_off=9984, row_off=18688, width=512, height=512),
#  Window(col_off=9984, row_off=19200, width=512, height=512),
#  Window(col_off=9984, row_off=19712, width=512, height=512),
#  Window(col_off=9984, row_off=19910, width=512, height=512),
#  Window(col_off=10496, row_off=256, width=512, height=512),
#  Window(col_off=10496, row_off=768, width=512, height=512),
#  Window(col_off=10496, row_off=1280, width=512, height=512),
#  Window(col_off=10496, row_off=1792, width=512, height=512),
#  Window(col_off=10496, row_off=2304, width=512, height=512),
#  Window(col_off=10496, row_off=2816, width=512, height=512),
#  Window(col_off=10496, row_off=3328, width=512, height=512),
#  Window(col_off=10496, row_off=3840, width=512, height=512),
#  Window(col_off=10496, row_off=4352, width=512, height=512),
#  Window(col_off=10496, row_off=4864, width=512, height=512),
#  Window(col_off=10496, row_off=5376, width=512, height=512),
#  Window(col_off=10496, row_off=5888, width=512, height=512),
#  Window(col_off=10496, row_off=6400, width=512, height=512),
#  Window(col_off=10496, row_off=6912, width=512, height=512),
#  Window(col_off=10496, row_off=7424, width=512, height=512),
#  Window(col_off=10496, row_off=7936, width=512, height=512),
#  Window(col_off=10496, row_off=8448, width=512, height=512),
#  Window(col_off=10496, row_off=8960, width=512, height=512),
#  Window(col_off=10496, row_off=9472, width=512, height=512),
#  Window(col_off=10496, row_off=9984, width=512, height=512),
#  Window(col_off=10496, row_off=10496, width=512, height=512),
#  Window(col_off=10496, row_off=11008, width=512, height=512),
#  Window(col_off=10496, row_off=11520, width=512, height=512),
#  Window(col_off=10496, row_off=12032, width=512, height=512),
#  Window(col_off=10496, row_off=12544, width=512, height=512),
#  Window(col_off=10496, row_off=13056, width=512, height=512),
#  Window(col_off=10496, row_off=13568, width=512, height=512),
#  Window(col_off=10496, row_off=14080, width=512, height=512),
#  Window(col_off=10496, row_off=14592, width=512, height=512),
#  Window(col_off=10496, row_off=15104, width=512, height=512),
#  Window(col_off=10496, row_off=15616, width=512, height=512),
#  Window(col_off=10496, row_off=16128, width=512, height=512),
#  Window(col_off=10496, row_off=16640, width=512, height=512),
#  Window(col_off=10496, row_off=17152, width=512, height=512),
#  Window(col_off=10496, row_off=17664, width=512, height=512),
#  Window(col_off=10496, row_off=18176, width=512, height=512),
#  Window(col_off=10496, row_off=18688, width=512, height=512),
#  Window(col_off=10496, row_off=19200, width=512, height=512),
#  Window(col_off=10496, row_off=19712, width=512, height=512),
#  Window(col_off=10496, row_off=19910, width=512, height=512),
#  Window(col_off=11008, row_off=256, width=512, height=512),
#  Window(col_off=11008, row_off=768, width=512, height=512),
#  Window(col_off=11008, row_off=1280, width=512, height=512),
#  Window(col_off=11008, row_off=1792, width=512, height=512),
#  Window(col_off=11008, row_off=2304, width=512, height=512),
#  Window(col_off=11008, row_off=2816, width=512, height=512),
#  Window(col_off=11008, row_off=3328, width=512, height=512),
#  Window(col_off=11008, row_off=3840, width=512, height=512),
#  Window(col_off=11008, row_off=4352, width=512, height=512),
#  Window(col_off=11008, row_off=4864, width=512, height=512),
#  Window(col_off=11008, row_off=5376, width=512, height=512),
#  Window(col_off=11008, row_off=5888, width=512, height=512),
#  Window(col_off=11008, row_off=6400, width=512, height=512),
#  Window(col_off=11008, row_off=6912, width=512, height=512),
#  Window(col_off=11008, row_off=7424, width=512, height=512),
#  Window(col_off=11008, row_off=7936, width=512, height=512),
#  Window(col_off=11008, row_off=8448, width=512, height=512),
#  Window(col_off=11008, row_off=8960, width=512, height=512),
#  Window(col_off=11008, row_off=9472, width=512, height=512),
#  Window(col_off=11008, row_off=9984, width=512, height=512),
#  Window(col_off=11008, row_off=10496, width=512, height=512),
#  Window(col_off=11008, row_off=11008, width=512, height=512),
#  Window(col_off=11008, row_off=11520, width=512, height=512),
#  Window(col_off=11008, row_off=12032, width=512, height=512),
#  Window(col_off=11008, row_off=12544, width=512, height=512),
#  Window(col_off=11008, row_off=13056, width=512, height=512),
#  Window(col_off=11008, row_off=13568, width=512, height=512),
#  Window(col_off=11008, row_off=14080, width=512, height=512),
#  Window(col_off=11008, row_off=14592, width=512, height=512),
#  Window(col_off=11008, row_off=15104, width=512, height=512),
#  Window(col_off=11008, row_off=15616, width=512, height=512),
#  Window(col_off=11008, row_off=16128, width=512, height=512),
#  Window(col_off=11008, row_off=16640, width=512, height=512),
#  Window(col_off=11008, row_off=17152, width=512, height=512),
#  Window(col_off=11008, row_off=17664, width=512, height=512),
#  Window(col_off=11008, row_off=18176, width=512, height=512),
#  Window(col_off=11008, row_off=18688, width=512, height=512),
#  Window(col_off=11008, row_off=19200, width=512, height=512),
#  Window(col_off=11008, row_off=19712, width=512, height=512),
#  Window(col_off=11008, row_off=19910, width=512, height=512),
#  Window(col_off=11520, row_off=256, width=512, height=512),
#  Window(col_off=11520, row_off=768, width=512, height=512),
#  Window(col_off=11520, row_off=1280, width=512, height=512),
#  Window(col_off=11520, row_off=1792, width=512, height=512),
#  Window(col_off=11520, row_off=2304, width=512, height=512),
#  Window(col_off=11520, row_off=2816, width=512, height=512),
#  Window(col_off=11520, row_off=3328, width=512, height=512),
#  Window(col_off=11520, row_off=3840, width=512, height=512),
#  Window(col_off=11520, row_off=4352, width=512, height=512),
#  Window(col_off=11520, row_off=4864, width=512, height=512),
#  Window(col_off=11520, row_off=5376, width=512, height=512),
#  Window(col_off=11520, row_off=5888, width=512, height=512),
#  Window(col_off=11520, row_off=6400, width=512, height=512),
#  Window(col_off=11520, row_off=6912, width=512, height=512),
#  Window(col_off=11520, row_off=7424, width=512, height=512),
#  Window(col_off=11520, row_off=7936, width=512, height=512),
#  Window(col_off=11520, row_off=8448, width=512, height=512),
#  Window(col_off=11520, row_off=8960, width=512, height=512),
#  Window(col_off=11520, row_off=9472, width=512, height=512),
#  Window(col_off=11520, row_off=9984, width=512, height=512),
#  Window(col_off=11520, row_off=10496, width=512, height=512),
#  Window(col_off=11520, row_off=11008, width=512, height=512),
#  Window(col_off=11520, row_off=11520, width=512, height=512),
#  Window(col_off=11520, row_off=12032, width=512, height=512),
#  Window(col_off=11520, row_off=12544, width=512, height=512),
#  Window(col_off=11520, row_off=13056, width=512, height=512),
#  Window(col_off=11520, row_off=13568, width=512, height=512),
#  Window(col_off=11520, row_off=14080, width=512, height=512),
#  Window(col_off=11520, row_off=14592, width=512, height=512),
#  Window(col_off=11520, row_off=15104, width=512, height=512),
#  Window(col_off=11520, row_off=15616, width=512, height=512),
#  Window(col_off=11520, row_off=16128, width=512, height=512),
#  Window(col_off=11520, row_off=16640, width=512, height=512),
#  Window(col_off=11520, row_off=17152, width=512, height=512),
#  Window(col_off=11520, row_off=17664, width=512, height=512),
#  Window(col_off=11520, row_off=18176, width=512, height=512),
#  Window(col_off=11520, row_off=18688, width=512, height=512),
#  Window(col_off=11520, row_off=19200, width=512, height=512),
#  Window(col_off=11520, row_off=19712, width=512, height=512),
#  Window(col_off=11520, row_off=19910, width=512, height=512),
#  Window(col_off=12032, row_off=256, width=512, height=512),
#  Window(col_off=12032, row_off=768, width=512, height=512),
#  Window(col_off=12032, row_off=1280, width=512, height=512),
#  Window(col_off=12032, row_off=1792, width=512, height=512),
#  Window(col_off=12032, row_off=2304, width=512, height=512),
#  Window(col_off=12032, row_off=2816, width=512, height=512),
#  Window(col_off=12032, row_off=3328, width=512, height=512),
#  Window(col_off=12032, row_off=3840, width=512, height=512),
#  Window(col_off=12032, row_off=4352, width=512, height=512),
#  Window(col_off=12032, row_off=4864, width=512, height=512),
#  Window(col_off=12032, row_off=5376, width=512, height=512),
#  Window(col_off=12032, row_off=5888, width=512, height=512),
#  Window(col_off=12032, row_off=6400, width=512, height=512),
#  Window(col_off=12032, row_off=6912, width=512, height=512),
#  Window(col_off=12032, row_off=7424, width=512, height=512),
#  Window(col_off=12032, row_off=7936, width=512, height=512),
#  Window(col_off=12032, row_off=8448, width=512, height=512),
#  Window(col_off=12032, row_off=8960, width=512, height=512),
#  Window(col_off=12032, row_off=9472, width=512, height=512),
#  Window(col_off=12032, row_off=9984, width=512, height=512),
#  Window(col_off=12032, row_off=10496, width=512, height=512),
#  Window(col_off=12032, row_off=11008, width=512, height=512),
#  Window(col_off=12032, row_off=11520, width=512, height=512),
#  Window(col_off=12032, row_off=12032, width=512, height=512),
#  Window(col_off=12032, row_off=12544, width=512, height=512),
#  Window(col_off=12032, row_off=13056, width=512, height=512),
#  Window(col_off=12032, row_off=13568, width=512, height=512),
#  Window(col_off=12032, row_off=14080, width=512, height=512),
#  Window(col_off=12032, row_off=14592, width=512, height=512),
#  Window(col_off=12032, row_off=15104, width=512, height=512),
#  Window(col_off=12032, row_off=15616, width=512, height=512),
#  Window(col_off=12032, row_off=16128, width=512, height=512),
#  Window(col_off=12032, row_off=16640, width=512, height=512),
#  Window(col_off=12032, row_off=17152, width=512, height=512),
#  Window(col_off=12032, row_off=17664, width=512, height=512),
#  Window(col_off=12032, row_off=18176, width=512, height=512),
#  Window(col_off=12032, row_off=18688, width=512, height=512),
#  Window(col_off=12032, row_off=19200, width=512, height=512),
#  Window(col_off=12032, row_off=19712, width=512, height=512),
#  Window(col_off=12032, row_off=19910, width=512, height=512),
#  Window(col_off=12544, row_off=256, width=512, height=512),
#  Window(col_off=12544, row_off=768, width=512, height=512),
#  Window(col_off=12544, row_off=1280, width=512, height=512),
#  Window(col_off=12544, row_off=1792, width=512, height=512),
#  Window(col_off=12544, row_off=2304, width=512, height=512),
#  Window(col_off=12544, row_off=2816, width=512, height=512),
#  Window(col_off=12544, row_off=3328, width=512, height=512),
#  Window(col_off=12544, row_off=3840, width=512, height=512),
#  Window(col_off=12544, row_off=4352, width=512, height=512),
#  Window(col_off=12544, row_off=4864, width=512, height=512),
#  Window(col_off=12544, row_off=5376, width=512, height=512),
#  Window(col_off=12544, row_off=5888, width=512, height=512),
#  Window(col_off=12544, row_off=6400, width=512, height=512),
#  Window(col_off=12544, row_off=6912, width=512, height=512),
#  Window(col_off=12544, row_off=7424, width=512, height=512),
#  Window(col_off=12544, row_off=7936, width=512, height=512),
#  Window(col_off=12544, row_off=8448, width=512, height=512),
#  Window(col_off=12544, row_off=8960, width=512, height=512),
#  Window(col_off=12544, row_off=9472, width=512, height=512),
#  Window(col_off=12544, row_off=9984, width=512, height=512),
#  Window(col_off=12544, row_off=10496, width=512, height=512),
#  Window(col_off=12544, row_off=11008, width=512, height=512),
#  Window(col_off=12544, row_off=11520, width=512, height=512),
#  Window(col_off=12544, row_off=12032, width=512, height=512),
#  Window(col_off=12544, row_off=12544, width=512, height=512),
#  Window(col_off=12544, row_off=13056, width=512, height=512),
#  Window(col_off=12544, row_off=13568, width=512, height=512),
#  Window(col_off=12544, row_off=14080, width=512, height=512),
#  Window(col_off=12544, row_off=14592, width=512, height=512),
#  Window(col_off=12544, row_off=15104, width=512, height=512),
#  Window(col_off=12544, row_off=15616, width=512, height=512),
#  Window(col_off=12544, row_off=16128, width=512, height=512),
#  Window(col_off=12544, row_off=16640, width=512, height=512),
#  Window(col_off=12544, row_off=17152, width=512, height=512),
#  Window(col_off=12544, row_off=17664, width=512, height=512),
#  Window(col_off=12544, row_off=18176, width=512, height=512),
#  Window(col_off=12544, row_off=18688, width=512, height=512),
#  Window(col_off=12544, row_off=19200, width=512, height=512),
#  Window(col_off=12544, row_off=19712, width=512, height=512),
#  Window(col_off=12544, row_off=19910, width=512, height=512),
#  ...]

# %%
loader_args = {
    "batch_size": 1,
    "num_workers": 4,
    "pin_memory": True,
    "shuffle": False,
}
inference_loader = DataLoader(dataset, **loader_args)

# %%
# preferably use GPU
device = torch.device("cuda:2" if torch.cuda.is_available() else "cpu")
device_ids = [0]
# model with three input channels (RGB)
model = UNet(
    n_channels=3,
    n_classes=1,
).to(memory_format=torch.channels_last)
load_model(model, model_path)
model = model.to(memory_format=torch.channels_last, device=device)

model.eval()
# Out:
# UNet(
#   (inc): DoubleConv(
#     (double_conv): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU(inplace=True)
#     )
#   )
#   (down1): Down(
#     (maxpool_conv): Sequential(
#       (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (1): DoubleConv(
#         (double_conv): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU(inplace=True)
#         )
#       )
#     )
#   )
#   (down2): Down(
#     (maxpool_conv): Sequential(
#       (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (1): DoubleConv(
#         (double_conv): Sequential(
#           (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU(inplace=True)
#         )
#       )
#     )
#   )
#   (down3): Down(
#     (maxpool_conv): Sequential(
#       (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (1): DoubleConv(
#         (double_conv): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU(inplace=True)
#         )
#       )
#     )
#   )
#   (down4): Down(
#     (maxpool_conv): Sequential(
#       (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (1): DoubleConv(
#         (double_conv): Sequential(
#           (0): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (4): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU(inplace=True)
#         )
#       )
#     )
#   )
#   (up1): Up(
#     (up): ConvTranspose2d(1024, 512, kernel_size=(2, 2), stride=(2, 2))
#     (conv): DoubleConv(
#       (double_conv): Sequential(
#         (0): Conv2d(1024, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU(inplace=True)
#       )
#     )
#   )
#   (up2): Up(
#     (up): ConvTranspose2d(512, 256, kernel_size=(2, 2), stride=(2, 2))
#     (conv): DoubleConv(
#       (double_conv): Sequential(
#         (0): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU(inplace=True)
#       )
#     )
#   )
#   (up3): Up(
#     (up): ConvTranspose2d(256, 128, kernel_size=(2, 2), stride=(2, 2))
#     (conv): DoubleConv(
#       (double_conv): Sequential(
#         (0): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU(inplace=True)
#       )
#     )
#   )
#   (up4): Up(
#     (up): ConvTranspose2d(128, 64, kernel_size=(2, 2), stride=(2, 2))
#     (conv): DoubleConv(
#       (double_conv): Sequential(
#         (0): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU(inplace=True)
#       )
#     )
#   )
#   (outc): OutConv(
#     (conv): Conv2d(64, 1, kernel_size=(1, 1), stride=(1, 1))
#   )
# )

# %%
if not os.path.exists(output_dir):
    os.makedirs(output_dir)
output_image_path = os.path.join(output_dir, filename)
output_image = rasterio.open(
    output_image_path,
    "w+",
    driver="GTiff",
    width=dataset.width,
    height=dataset.height,
    count=1,
    dtype=rasterio.uint8,
    crs=dataset.image_src.crs,
    transform=dataset.image_src.transform,
    compress="DEFLATE",
)


for images, cropped_windows in tqdm(inference_loader):
    images = images.to(device=device, memory_format=torch.channels_last)
    with torch.no_grad():
        output = model(images)
        output = torch.sigmoid(output)
        output = (output > 0.3).float()

        # crop tensor by dataset padding
        output = crop(
            output,
            top=dataset.padding,
            left=dataset.padding,
            height=dataset.tile_size - (2 * dataset.padding),
            width=dataset.tile_size - (2 * dataset.padding),
        )

        # add white edge to image of two pixels
        # output = torch.nn.functional.pad(output, (2, 2, 2, 2), value=2)

        output_image.write(
            output[0].cpu().numpy(),
            window=windows.Window(
                cropped_windows["col_off"].item(),
                cropped_windows["row_off"].item(),
                cropped_windows["width"].item(),
                cropped_windows["height"].item(),
            ),
        )
output_image.close()
# Out:
# 100%|██████████| 3200/3200 [03:04<00:00, 17.39it/s]
