# %%
import pandas as pd
import numpy as np

# %%
register_file = "/net/scratch/jmoehring/tiles_register.csv"

# %%
register_df = pd.read_csv(register_file, index_col=0)

# %%
bins = np.arange(0.00, 0.22, 0.02)
register_df["resolution"].hist(bins=bins)
# Out:
# <Axes: >

# %%
np.digitize(0.0001, bins,right=False)
# Out:
# 1
